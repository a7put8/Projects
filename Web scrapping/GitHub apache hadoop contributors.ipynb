# %%
## Import required libraries
import requests
from bs4 import BeautifulSoup
import json
import time

## Github authentication username and token
username = 'a7put8'
token = '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'

url = 'https://api.github.com/repos/apache/hadoop/contributors?per_page=100'

page = requests.get(url, auth = (username,token))

data = BeautifulSoup(page.content, 'html.parser')

json_dict = json.loads(str(data)) ## convert into json object

# %%
#json_dict

# %%
## Get required details
login_list = []
ID = []
location = []
email = []
hireable = []
bio = []
twitter = []
public_r = []
public_g = []
followers = []
following = []
created = []


for i in range(len(json_dict)):
    login = json_dict[i]['login'] ## Get username from given url
    
    user_url = f"https://api.github.com/users/{login}" 

    page_1 = requests.get(user_url, auth = (username,token)) ## Go to user page to get the necessary data

    data_1 = BeautifulSoup(page_1.content, 'html.parser') ## Create BeautifulSoup instance

    details = json.loads(str(data_1)) ## create json object
    
    print(f"Login : {json_dict[i]['login']}")
    print(f"ID : {json_dict[i]['id']}")
    print(f"Location : {details['location']}")
    print(f"Email : {details['email']}")
    print(f"Hireable : {details['hireable']}")
    print(f"Bio : {details['bio']}")
    print(f"Twitter Username : {details['twitter_username']}")
    print(f"Public Repos : {details['public_repos']}")
    print(f"Public gists : {details['public_gists']}")
    print(f"Followers : {details['followers']}")
    print(f"Following : {details['following']}")
    print(f"Created at : {details['created_at']}")
    print("\n")
    
    login_list.append(json_dict[i]['login'])
    ID.append(json_dict[i]['id'])
    location.append(details['location'])
    email.append(details['email'])
    hireable.append(details['hireable'])
    bio.append(details['bio'])
    twitter.append(details['twitter_username'])
    public_r.append(details['public_repos'])
    public_g.append(details['public_gists'])
    followers.append(details['followers'])
    following.append(details['following'])
    created.append(details['created_at'])
    
    time.sleep(10)
# Out:
# Login : aajisaka
# ID : 3403122
# Location : Tokyo, Japan
# Email : None
# Hireable : None
# Bio : Software engineer @aws Glue. Apache (@apache) Hadoop/Yetus/Incubator committer and PMC member. Apache Member. I like OSS and distributed systems.
# Twitter Username : ajis_ka
# Public Repos : 34
# Public gists : 43
# Followers : 241
# Following : 48
# Created at : 2013-01-28T07:02:40Z
#
#
# Login : vinoduec
# ID : 384796
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 1
# Public gists : 1
# Followers : 39
# Following : 0
# Created at : 2010-09-02T07:32:46Z
#
#
# Login : szetszwo
# ID : 907380
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 6
# Public gists : 0
# Followers : 83
# Following : 0
# Created at : 2011-07-11T09:30:08Z
#
#
# Login : arp7
# ID : 2480225
# Location : Santa Clara, California
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 14
# Public gists : 1
# Followers : 33
# Following : 2
# Created at : 2012-10-03T15:51:33Z
#
#
# Login : steveloughran
# ID : 162090
# Location : Bristol, England
# Email : None
# Hireable : None
# Bio : Afraid I am not a reviewing any issues/PRs that or not critical. Sorry
# Twitter Username : None
# Public Repos : 53
# Public gists : 13
# Followers : 449
# Following : 2
# Created at : 2009-12-04T18:56:43Z
#
#
# Login : cnauroth
# ID : 227407
# Location : Seattle, WA
# Email : cnauroth@apache.org
# Hireable : None
# Bio : Software engineer at Google Cloud Dataproc.  Apache Hadoop PMC member.  ASF member.  The opinions stated here are my own, not necessarily those of my employer.
# Twitter Username : cnauroth
# Public Repos : 34
# Public gists : 5
# Followers : 83
# Following : 17
# Created at : 2010-03-21T18:06:44Z
#
#
# Login : jlowe
# ID : 1360766
# Location : Champaign, IL
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 10
# Public gists : 0
# Followers : 28
# Following : 0
# Created at : 2012-01-20T22:15:01Z
#
#
# Login : umbrant
# ID : 33948
# Location : None
# Email : andrew@umbrant.com
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 33
# Public gists : 4
# Followers : 94
# Following : 4
# Created at : 2008-11-11T23:57:45Z
#
#
# Login : toddlipcon
# ID : 14135
# Location : San Francisco, CA
# Email : todd@lipcon.org
# Hireable : None
# Bio : None
# Twitter Username : tlipcon
# Public Repos : 103
# Public gists : 276
# Followers : 432
# Following : 8
# Created at : 2008-06-18T03:04:16Z
#
#
# Login : anuengineer
# ID : 2831777
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 22
# Public gists : 0
# Followers : 19
# Following : 3
# Created at : 2012-11-19T05:35:44Z
#
#
# Login : atm
# ID : 148338
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : atm
# Public Repos : 5
# Public gists : 0
# Followers : 28
# Following : 0
# Created at : 2009-11-03T15:19:34Z
#
#
# Login : elicollins
# ID : 131502
# Location : California
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 6
# Public gists : 0
# Followers : 32
# Following : 1
# Created at : 2009-09-26T05:57:26Z
#
#
# Login : jian-he
# ID : 3662775
# Location : None
# Email : None
# Hireable : None
# Bio : Now at Alibaba, previously at  Hortonworks.
# Hadoop Committer &amp; PMC
#
# Twitter Username : None
# Public Repos : 30
# Public gists : 0
# Followers : 91
# Following : 0
# Created at : 2013-02-21T19:34:51Z
#
#
# Login : Jing9
# ID : 359132
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 0
# Public gists : 0
# Followers : 17
# Following : 2
# Created at : 2010-08-09T21:41:03Z
#
#
# Login : acmurthy
# ID : 316888
# Location : None
# Email : acm@hortonworks.com
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 5
# Public gists : 0
# Followers : 49
# Following : 0
# Created at : 2010-06-28T22:18:22Z
#
#
# Login : wangdatan
# ID : 20328673
# Location : Santa Clara
# Email : wangda@apache.org
# Hireable : None
# Bio : Co-Founder of waii.ai. Ex-Snowflake/Cloudera/Alibaba,
# Apache Hadoop/Submarine/YuniKorn PMC member, ASF Member.
# Twitter Username : None
# Public Repos : 8
# Public gists : 0
# Followers : 48
# Following : 0
# Created at : 2016-07-06T23:49:45Z
#
#
# Login : xiaoyuyao
# ID : 7039184
# Location : None
# Email : xiaoyuyao@gmail.com
# Hireable : None
# Bio : Apache Hadoop PMC and Committer. Working on Open Source Software: Hadoop/HDFS/Ozone.
# Twitter Username : None
# Public Repos : 60
# Public gists : 1
# Followers : 33
# Following : 2
# Created at : 2014-03-23T15:42:25Z
#
#
# Login : kihwal
# ID : 340000
# Location : None
# Email : None
# Hireable : None
# Bio : @apache Hadoop Committer and a member of Hadoop PMC.
# Software Engineer at @yahoo.
# Extra Class amateur radio operator, a life member of @Arrl.
# Twitter Username : None
# Public Repos : 18
# Public gists : 0
# Followers : 10
# Following : 0
# Created at : 2010-07-21T18:09:50Z
#
#
# Login : kambatla
# ID : 648114
# Location : Mountain View, CA
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 15
# Public gists : 0
# Followers : 20
# Following : 4
# Created at : 2011-03-03T01:12:39Z
#
#
# Login : sunilgovind
# ID : 7998680
# Location : None
# Email : sunilg@apache.org
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 5
# Public gists : 0
# Followers : 16
# Following : 3
# Created at : 2014-06-26T18:06:13Z
#
#
# Login : szilard-nemeth
# ID : 954799
# Location : Atlanta, GA
# Email : None
# Hireable : None
# Bio : An enthusiastic SW Engineer who loves coding, SW design and tinkering with his projects. True believer of automation. Simple as that.
# +Apache Hadoop PMC member
# Twitter Username : szilard_nemeth
# Public Repos : 52
# Public gists : 0
# Followers : 14
# Following : 23
# Created at : 2011-08-02T18:36:40Z
#
#
# Login : aw-was-here
# ID : 7633626
# Location : San Jose, CA, USA, Earth, Solar System, Orion-Cygnus Arm, Milky Way
# Email : aw@apache.org
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 24
# Public gists : 0
# Followers : 18
# Following : 0
# Created at : 2014-05-19T17:54:13Z
#
#
# Login : ayushtkn
# ID : 25608848
# Location : India
# Email : ayushsaxena@apache.org
# Hireable : None
# Bio : ASF Member, Apache Hadoop, Hive, Ozone &amp; Incubator PMC Member &amp; Committer, Apache Tez Committer
# Twitter Username : ayuushsaxena
# Public Repos : 11
# Public gists : 0
# Followers : 38
# Following : 0
# Created at : 2017-02-07T10:34:19Z
#
#
# Login : revans2
# ID : 3441321
# Location : Champaign IL
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 22
# Public gists : 5
# Followers : 141
# Following : 0
# Created at : 2013-01-31T18:51:35Z
#
#
# Login : vinayakumarb
# ID : 15498544
# Location : None
# Email : vinayakumarb@apache.org
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 21
# Public gists : 0
# Followers : 9
# Following : 0
# Created at : 2015-10-31T02:16:35Z
#
#
# Login : macroadster
# ID : 328366
# Location : None
# Email : eric818@gmail.com
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 6
# Public gists : 0
# Followers : 3
# Following : 0
# Created at : 2010-07-10T17:18:31Z
#
#
# Login : slfan1989
# ID : 55643692
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 76
# Public gists : 0
# Followers : 28
# Following : 16
# Created at : 2019-09-22T02:49:02Z
#
#
# Login : jojochuang
# ID : 2691807
# Location : None
# Email : None
# Hireable : None
# Bio : Apache Member. I work on many Apache projects.
# Twitter Username : None
# Public Repos : 52
# Public gists : 3
# Followers : 59
# Following : 0
# Created at : 2012-10-31T14:28:11Z
#
#
# Login : JunpingDu
# ID : 888093
# Location : SF
# Email : junping_du@apache.org
# Hireable : True
# Bio : Founder of Datastrato
# Twitter Username : None
# Public Repos : 37
# Public gists : 0
# Followers : 217
# Following : 8
# Created at : 2011-07-01T06:27:41Z
#
#
# Login : tomwhite
# ID : 85085
# Location : Wales, UK
# Email : tom.e.white@gmail.com
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 205
# Public gists : 3
# Followers : 921
# Following : 2
# Created at : 2009-05-15T20:30:34Z
#
#
# Login : bharatviswa504
# ID : 8586345
# Location : Canada
# Email : bharat@apache.org
# Hireable : True
# Bio : None
# Twitter Username : None
# Public Repos : 37
# Public gists : 0
# Followers : 9
# Following : 4
# Created at : 2014-08-29T02:38:41Z
#
#
# Login : yangwwei
# ID : 14214570
# Location : California
# Email : wwei@apache.org
# Hireable : None
# Bio : AI infra @Apple @apache  @CNCF
# Twitter Username : None
# Public Repos : 24
# Public gists : 0
# Followers : 68
# Following : 0
# Created at : 2015-09-10T08:44:10Z
#
#
# Login : elek
# ID : 170549
# Location : None
# Email : None
# Hireable : True
# Bio : None
# Twitter Username : None
# Public Repos : 281
# Public gists : 40
# Followers : 105
# Following : 25
# Created at : 2009-12-21T15:17:38Z
#
#
# Login : rohithsharmaks
# ID : 15336756
# Location : Atlanta, Georgia
# Email : rohithsharmaks@apache.org
# Hireable : None
# Bio : None
# Twitter Username : rohithsharmaks
# Public Repos : 14
# Public gists : 0
# Followers : 4
# Following : 0
# Created at : 2015-10-27T05:12:35Z
#
#
# Login : oza
# ID : 104111
# Location : Tokyo, Japan
# Email : ozawa.tsuyoshi@gmail.com
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 64
# Public gists : 84
# Followers : 90
# Following : 54
# Created at : 2009-07-12T11:50:13Z
#
#
# Login : linyiqun
# ID : 7877836
# Location : Shanghai, China
# Email : None
# Hireable : None
# Bio : Apache Hadoop PMC &amp; Apache Ozone PMC, mainly focus on distributed storage. I do believe code can change the world!
# Twitter Username : None
# Public Repos : 22
# Public gists : 0
# Followers : 1033
# Following : 10
# Created at : 2014-06-13T06:53:45Z
#
#
# Login : cmccabe
# ID : 1095624
# Location : Sunnyvale, CA
# Email : colin@cmccabe.xyz
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 57
# Public gists : 2
# Followers : 77
# Following : 0
# Created at : 2011-10-01T22:28:19Z
#
#
# Login : xiao-chen
# ID : 14279024
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 17
# Public gists : 2
# Followers : 15
# Following : 11
# Created at : 2015-09-14T16:40:54Z
#
#
# Login : rkanter
# ID : 3588587
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 16
# Public gists : 0
# Followers : 21
# Following : 4
# Created at : 2013-02-13T22:06:12Z
#
#
# Login : virajjasani
# ID : 34790606
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 16
# Public gists : 0
# Followers : 17
# Following : 0
# Created at : 2017-12-23T10:56:25Z
#
#
# Login : liuml07
# ID : 159186
# Location : San Francisco Bay Area
# Email : liuml07@apache.org
# Hireable : None
# Bio : Innocent Contributor.
# Twitter Username : liuml07
# Public Repos : 9
# Public gists : 10
# Followers : 128
# Following : 62
# Created at : 2009-11-28T13:19:27Z
#
#
# Login : xslogic
# ID : 31204
# Location : Sunnyvale, CA
# Email : asuresh@apache.org
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 22
# Public gists : 6
# Followers : 39
# Following : 5
# Created at : 2008-10-27T08:54:58Z
#
#
# Login : cdouglas
# ID : 145508
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 3
# Public gists : 2
# Followers : 21
# Following : 6
# Created at : 2009-10-27T21:46:30Z
#
#
# Login : umamaheswararao
# ID : 1719507
# Location : Santa Clara, CA, USA
# Email : umamahesh@apache.org
# Hireable : None
# Bio : http://people.apache.org/~umamahesh/umamahesh.html
# Twitter Username : None
# Public Repos : 21
# Public gists : 0
# Followers : 7
# Following : 0
# Created at : 2012-05-08T20:21:50Z
#
#
# Login : zjshen14
# ID : 35021395
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 20
# Public gists : 13
# Followers : 25
# Following : 6
# Created at : 2018-01-02T05:40:36Z
#
#
# Login : nandakumar131
# ID : 8871229
# Location : Chennai
# Email : nandakumar131@gmail.com
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 16
# Public gists : 0
# Followers : 16
# Following : 0
# Created at : 2014-09-23T05:51:39Z
#
#
# Login : sryza
# ID : 654855
# Location : San Francisco
# Email : sandyryza@gmail.com
# Hireable : None
# Bio : None
# Twitter Username : s_ryz
# Public Repos : 48
# Public gists : 10
# Followers : 585
# Following : 20
# Created at : 2011-03-07T03:31:41Z
#
#
# Login : shvachko
# ID : 11998604
# Location : San Francisco Bay Area
# Email : kshvachko@linkedin.com
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 2
# Public gists : 3
# Followers : 12
# Following : 0
# Created at : 2015-04-17T18:42:22Z
#
#
# Login : xgong
# ID : 3181402
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 14
# Public gists : 0
# Followers : 3
# Following : 1
# Created at : 2013-01-04T00:15:55Z
#
#
# Login : templedf
# ID : 651386
# Location : Palo Alto
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 12
# Public gists : 1
# Followers : 22
# Following : 0
# Created at : 2011-03-04T17:34:25Z
#
#
# Login : iwasakims
# ID : 1856607
# Location : None
# Email : iwasakims@apache.org
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 49
# Public gists : 0
# Followers : 29
# Following : 2
# Created at : 2012-06-16T12:03:54Z
#
#
# Login : brahmareddybattula
# ID : 1954406
# Location : Bangalore
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : brahmareddyb
# Public Repos : 9
# Public gists : 0
# Followers : 8
# Following : 7
# Created at : 2012-07-11T05:38:15Z
#
#
# Login : tgravescs
# ID : 4563792
# Location : None
# Email : tgraves_cs@yahoo.com
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 21
# Public gists : 2
# Followers : 60
# Following : 0
# Created at : 2013-05-29T20:48:16Z
#
#
# Login : sidseth
# ID : 1817602
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 14
# Public gists : 0
# Followers : 11
# Following : 1
# Created at : 2012-06-05T02:09:17Z
#
#
# Login : zhe-thoughts
# ID : 10713559
# Location : Sunnyvale, CA, USA
# Email : zhz@apache.org
# Hireable : None
# Bio : Zhe leads the @ray-project Ray.io team at @anyscale
# Twitter Username : zhz_ray
# Public Repos : 17
# Public gists : 0
# Followers : 85
# Following : 141
# Created at : 2015-01-26T18:59:17Z
#
#
# Login : varunsaxena
# ID : 10049695
# Location : Bangalore
# Email : vasaxena@linkedin.com
# Hireable : None
# Bio : Apache Hadoop PMC and Committer, Staff Engineer @ LinkedIn
# Twitter Username : None
# Public Repos : 16
# Public gists : 0
# Followers : 7
# Following : 8
# Created at : 2014-12-02T16:24:27Z
#
#
# Login : QwertyManiac
# ID : 31518
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 4
# Public gists : 0
# Followers : 77
# Following : 1
# Created at : 2008-10-28T20:39:50Z
#
#
# Login : jnp
# ID : 903890
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 11
# Public gists : 0
# Followers : 2
# Following : 1
# Created at : 2011-07-08T23:04:41Z
#
#
# Login : haibchen
# ID : 5755773
# Location : Mountain View
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 5
# Public gists : 0
# Followers : 10
# Following : 8
# Created at : 2013-10-23T11:45:11Z
#
#
# Login : GauthamBanasandra
# ID : 10280768
# Location : Bangalore
# Email : gautham.bangalore@gmail.com
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 58
# Public gists : 17
# Followers : 32
# Following : 6
# Created at : 2014-12-23T13:56:33Z
#
#
# Login : mukul1987
# ID : 4317412
# Location : Bangalore
# Email : msingh@confluent.io
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 27
# Public gists : 0
# Followers : 7
# Following : 0
# Created at : 2013-05-02T03:23:25Z
#
#
# Login : bshashikant
# ID : 31469764
# Location : None
# Email : shashioct19@gmail.com
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 4
# Public gists : 0
# Followers : 2
# Following : 0
# Created at : 2017-08-30T08:07:39Z
#
#
# Login : sjlee
# ID : 197079
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 15
# Public gists : 4
# Followers : 31
# Following : 0
# Created at : 2010-02-04T21:05:18Z
#
#
# Login : tasanuma
# ID : 11712443
# Location : Tokyo, Japan
# Email : None
# Hireable : None
# Bio : Software Engineer, Apache Hadoop Committer
# Twitter Username : None
# Public Repos : 14
# Public gists : 1
# Followers : 23
# Following : 12
# Created at : 2015-03-30T01:55:03Z
#
#
# Login : ashutoshcipher
# ID : 17571497
# Location : London
# Email : None
# Hireable : None
# Bio : AWS - EMR hadoop and Spark-Perf
#
# Twitter Username : None
# Public Repos : 20
# Public gists : 0
# Followers : 8
# Following : 16
# Created at : 2016-03-01T14:41:45Z
#
#
# Login : billierinaldi
# ID : 1810597
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 12
# Public gists : 2
# Followers : 4
# Following : 0
# Created at : 2012-06-02T19:56:36Z
#
#
# Login : tomscut
# ID : 55134131
# Location : Singapore
# Email : tomscut@apache.org
# Hireable : None
# Bio : Apache Hadoop Committer &amp;
# CNCF CubeFS Committer.
# Keep Learning~
# Twitter Username : None
# Public Repos : 148
# Public gists : 0
# Followers : 34
# Following : 40
# Created at : 2019-09-10T09:04:25Z
#
#
# Login : adoroszlai
# ID : 6454655
# Location : Hungary
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 83
# Public gists : 0
# Followers : 36
# Following : 0
# Created at : 2014-01-20T21:34:08Z
#
#
# Login : subru
# ID : 2194334
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 1
# Public gists : 0
# Followers : 1
# Following : 0
# Created at : 2012-08-22T05:57:39Z
#
#
# Login : varun-vasu
# ID : 45411708
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 0
# Public gists : 0
# Followers : 0
# Following : 0
# Created at : 2018-11-28T02:47:30Z
#
#
# Login : surendralilhore
# ID : 45159337
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 3
# Public gists : 0
# Followers : 2
# Following : 0
# Created at : 2018-11-19T05:26:48Z
#
#
# Login : naga-apache
# ID : 50343640
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 0
# Public gists : 0
# Followers : 0
# Following : 0
# Created at : 2019-05-06T22:29:19Z
#
#
# Login : y-liu
# ID : 5966204
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 1
# Public gists : 0
# Followers : 1
# Following : 0
# Created at : 2013-11-18T06:54:26Z
#
#
# Login : omalley
# ID : 206536
# Location : Sunnyvale, CA
# Email : omalley@apache.org
# Hireable : None
# Bio : I'm a software engineer that has been working on big data open source projects since 2006. I'm a PMC member of Hadoop, Hive, and ORC.
# Twitter Username : None
# Public Repos : 32
# Public gists : 13
# Followers : 128
# Following : 9
# Created at : 2010-02-19T06:37:46Z
#
#
# Login : bibinchundatt
# ID : 11779290
# Location : Bangalore
# Email : bibinchundatt@gmail.com
# Hireable : True
# Bio : Apache Hadoop PMC member
# Twitter Username : None
# Public Repos : 7
# Public gists : 0
# Followers : 3
# Following : 2
# Created at : 2015-04-03T01:15:53Z
#
#
# Login : Hexiaoqiao
# ID : 1393756
# Location : Beijing
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 45
# Public gists : 0
# Followers : 100
# Following : 47
# Created at : 2012-01-31T07:10:01Z
#
#
# Login : hanishakoneru
# ID : 10237377
# Location : San Jose, CA
# Email : None
# Hireable : True
# Bio : None
# Twitter Username : None
# Public Repos : 7
# Public gists : 0
# Followers : 1
# Following : 0
# Created at : 2014-12-18T21:54:35Z
#
#
# Login : xkrogen
# ID : 6570401
# Location : Bay Area
# Email : xkrogen@apache.org
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 16
# Public gists : 0
# Followers : 21
# Following : 1
# Created at : 2014-02-02T22:48:21Z
#
#
# Login : haiyang1987
# ID : 3760130
# Location : None
# Email : huhaiyang926@126.com
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 279
# Public gists : 0
# Followers : 7
# Following : 50
# Created at : 2013-03-04T02:41:45Z
#
#
# Login : flyrain
# ID : 1322359
# Location : None
# Email : yufei@apache.org
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 24
# Public gists : 2
# Followers : 16
# Following : 0
# Created at : 2012-01-11T17:08:14Z
#
#
# Login : pbacsko
# ID : 22025731
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 7
# Public gists : 0
# Followers : 3
# Following : 1
# Created at : 2016-09-06T10:15:19Z
#
#
# Login : smengcl
# ID : 50227127
# Location : Palo Alto, CA
# Email : None
# Hireable : None
# Bio : Software Engineer @ Cloudera / Apache Hadoop Committer / Apache Ozone PMC &amp; Committer / This is a work account :)
# Twitter Username : None
# Public Repos : 16
# Public gists : 0
# Followers : 6
# Following : 0
# Created at : 2019-05-03T05:27:06Z
#
#
# Login : amahussein
# ID : 50450311
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 12
# Public gists : 0
# Followers : 4
# Following : 1
# Created at : 2019-05-09T12:23:42Z
#
#
# Login : ZanderXu
# ID : 17900637
# Location : beijing
# Email : xuzq_zander@163.com
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 23
# Public gists : 0
# Followers : 21
# Following : 22
# Created at : 2016-03-17T09:22:59Z
#
#
# Login : ericbadger
# ID : 43999255
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 0
# Public gists : 0
# Followers : 0
# Following : 0
# Created at : 2018-10-09T15:50:24Z
#
#
# Login : jianghuazhu
# ID : 6416939
# Location : HangZhou
# Email : 740087514@qq.com
# Hireable : None
# Bio : 《Hadoop HDFS深度剖析与实践》一书作者
# Twitter Username : None
# Public Repos : 35
# Public gists : 0
# Followers : 9
# Following : 22
# Created at : 2014-01-16T06:24:02Z
#
#
# Login : mukund-thakur
# ID : 10720944
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 9
# Public gists : 0
# Followers : 7
# Following : 2
# Created at : 2015-01-27T06:34:52Z
#
#
# Login : pjfanning
# ID : 11783444
# Location : Kilkenny, Ireland
# Email : None
# Hireable : None
# Bio : Experienced developer with an interest in open source. Member of Apache Software Foundation.
# Twitter Username : None
# Public Repos : 323
# Public gists : 0
# Followers : 139
# Following : 2
# Created at : 2015-04-03T08:56:14Z
#
#
# Login : virajith
# ID : 5614738
# Location : Sunnyvale, CA
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 0
# Public gists : 0
# Followers : 2
# Following : 0
# Created at : 2013-10-04T22:16:50Z
#
#
# Login : rakeshadr
# ID : 8215991
# Location : Bangalore
# Email : rakeshr@apache.org
# Hireable : None
# Bio : Apache committer &amp; PMC member - Ozone, Hadoop, ZooKeeper, BookKeeper projects. Mainly focussing on distributed storage systems.
# Twitter Username : rakeshadr
# Public Repos : 9
# Public gists : 0
# Followers : 7
# Following : 7
# Created at : 2014-07-20T13:43:33Z
#
#
# Login : erichadoop
# ID : 74205577
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 0
# Public gists : 0
# Followers : 0
# Following : 0
# Created at : 2020-11-09T17:56:21Z
#
#
# Login : mingmasplace
# ID : 2583464
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 1
# Public gists : 2
# Followers : 0
# Following : 0
# Created at : 2012-10-17T19:20:51Z
#
#
# Login : jghoman
# ID : 95350
# Location : Seattle
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 166
# Public gists : 10
# Followers : 138
# Following : 41
# Created at : 2009-06-14T21:30:03Z
#
#
# Login : hungj
# ID : 2773275
# Location : None
# Email : jhung@linkedin.com
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 9
# Public gists : 0
# Followers : 10
# Following : 0
# Created at : 2012-11-11T19:55:06Z
#
#
# Login : mehakmeet
# ID : 25390047
# Location : None
# Email : None
# Hireable : None
# Bio : Cloud Connectors and Algorithms.
# Twitter Username : None
# Public Repos : 35
# Public gists : 0
# Followers : 11
# Following : 7
# Created at : 2017-01-27T16:36:12Z
#
#
# Login : gerashegalov
# ID : 3187938
# Location : San Francisco, CA
# Email : gera@apache.org
# Hireable : None
# Bio : database &amp; ml engineering
# Twitter Username : gerashegalov
# Public Repos : 34
# Public gists : 0
# Followers : 17
# Following : 6
# Created at : 2013-01-04T19:14:06Z
#
#
# Login : vivekratnavel
# ID : 1051198
# Location : Santa Clara
# Email : vivekratnavel90@gmail.com
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 26
# Public gists : 1
# Followers : 28
# Following : 6
# Created at : 2011-09-14T19:25:16Z
#
#
# Login : 9uapaw
# ID : 24417674
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 15
# Public gists : 0
# Followers : 5
# Following : 7
# Created at : 2016-12-06T18:38:41Z
#
#
# Login : sborya
# ID : 959768
# Location : None
# Email : None
# Hireable : None
# Bio : None
# Twitter Username : None
# Public Repos : 4
# Public gists : 0
# Followers : 1
# Following : 0
# Created at : 2011-08-04T19:27:33Z
#
#
# Login : abmodi
# ID : 3080594
# Location : Bangalore
# Email : abmodi@apache.org
# Hireable : None
# Bio : Learning big-data.
# Twitter Username : None
# Public Repos : 28
# Public gists : 0
# Followers : 9
# Following : 3
# Created at : 2012-12-19T12:16:02Z

# %%
## Create a dictionary to store scrapped data
data = {'login': login_list, 'id': ID, 'location': location, 'email': email, 'hireable': hireable, 
        'bio': bio, 'twitter_username': twitter, 'public_repos': public_r, 'piblic_gists': public_g, 'followers': followers,
       'following': following, 'created_at': created}

# %%
## Convert dictionary to pandas data frame to handle null values and assign appropriate data types
import pandas as pd

df = pd.DataFrame(data)

df.info()

df['login'] = df['login'].astype('str')
df['location'] = df['location'].astype('str').fillna('not available')
df['email'] = df['email'].astype('str').fillna('no email')
df['hireable'] = df['hireable'].astype('str').fillna('no status')
df['bio'] = df['bio'].astype('str').fillna('no bio')
df['twitter_username'] = df['twitter_username'].astype('str').fillna('no username')
df['created_at'] = pd.to_datetime(df['created_at'], utc=True)
df['created_at'] = df['created_at'].dt.strftime('%Y-%m-%d %H:%M:%S')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   login             100 non-null    object
#  1   id                100 non-null    int64
#  2   location          53 non-null     object
#  3   email             44 non-null     object
#  4   hireable          5 non-null      object
#  5   bio               29 non-null     object
#  6   twitter_username  13 non-null     object
#  7   public_repos      100 non-null    int64
#  8   piblic_gists      100 non-null    int64
#  9   followers         100 non-null    int64
#  10  following         100 non-null    int64
#  11  created_at        100 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 9.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   login             100 non-null    object
#  1   id                100 non-null    int64
#  2   location          100 non-null    object
#  3   email             100 non-null    object
#  4   hireable          100 non-null    object
#  5   bio               100 non-null    object
#  6   twitter_username  100 non-null    object
#  7   public_repos      100 non-null    int64
#  8   piblic_gists      100 non-null    int64
#  9   followers         100 non-null    int64
#  10  following         100 non-null    int64
#  11  created_at        100 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 9.5+ KB

# %%
#!pip install mysql-connector-python
## Create new schema
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="Asa@9298"
)

mycursor = mydb.cursor()

mycursor.execute("DROP SCHEMA IF EXISTS HadoopContributors")
mycursor.execute("CREATE DATABASE HadoopContributors")

# %%
## Check if new schema created
mycursor.execute("SHOW DATABASES")
for x in mycursor:
  print(x)
# Out:
# ('accountspayable',)
# ('apachehadoopcontributors',)
# ('colonial',)
# ('entertainmentagencyexample',)
# ('hadoopcontributors',)
# ('information_schema',)
# ('moviestore',)
# ('mysql',)
# ('performance_schema',)
# ('prestigecars',)
# ('sakila',)
# ('sys',)
# ('vehicleinsurancefraud',)
# ('world',)

# %%
## Check if 100 unique contributors' info was scrapped
df['id'].nunique()
# Out:
# 100

# %% [markdown]
# For the SQL database, I would choose ID as the primary key as it is unique and of the type integer

# %%
## Create MySQL table to store the data with appropriate column types
mydb = mysql.connector.connect(
    host="localhost", 
    user="root", 
    password="Asa@9298",
    database = "HadoopContributors")

mycursor = mydb.cursor()

mycursor.execute("DROP TABLE IF EXISTS CONTRIBUTORS")

sql ='''CREATE TABLE CONTRIBUTORS(
   login CHAR(20),
   id INT UNSIGNED NOT NULL,
   location VARCHAR(200),
   email VARCHAR(200),
   hireable CHAR(50),
   bio VARCHAR(500),
   twitter_username VARCHAR(20),
   public_repos SMALLINT,
   piblic_gists SMALLINT,
   followers MEDIUMINT,
   following MEDIUMINT,
   created_at DATETIME,
   PRIMARY KEY (id)
)'''
mycursor.execute(sql)

# %%
## Push pandas df to MySQL database
from sqlalchemy import create_engine

hostname = "localhost"
username = "root"
password = "Asa%409298"
database_name = "HadoopContributors"

database_url = f"mysql+mysqlconnector://{username}:{password}@{hostname}/{database_name}"
engine = create_engine(database_url)

table_name = 'CONTRIBUTORS'

df.to_sql(name=table_name, con=engine, if_exists='append', index=False)
# Out:
# C:\Users\ADITYA A SATPUTE\AppData\Local\Temp\ipykernel_6768\3133696144.py:14: UserWarning: The provided table name 'CONTRIBUTORS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(name=table_name, con=engine, if_exists='append', index=False)
# 100

# %% [markdown]
# - A way to boost speed of the queries is to index the table
# - Using appropriate data type can also help. As it can be observed small and medium int have been used for some columns to reduce storage alloted and oncrease efficiency
# - Indexing other columns which would be frequently used

# %%
## Add index to improve performance
mycursor.execute("ALTER TABLE contributors ADD INDEX id_idx (id);") ## index primary key
mycursor.execute("CREATE INDEX email_idx ON contributors(email);") ## index email column as it could be used for joins as it could serve as a candidate key

# %%
## Display results
mycursor.execute("SELECT * FROM contributors") 
result = mycursor.fetchall() 
for row in result: 
    print(row, '\n')
# Out:
# ('toddlipcon', 14135, 'San Francisco, CA', 'todd@lipcon.org', 'None', 'None', 'tlipcon', 103, 276, 432, 8, datetime.datetime(2008, 6, 18, 3, 4, 16))
#
# ('xslogic', 31204, 'Sunnyvale, CA', 'asuresh@apache.org', 'None', 'None', 'None', 22, 6, 39, 5, datetime.datetime(2008, 10, 27, 8, 54, 58))
#
# ('QwertyManiac', 31518, 'None', 'None', 'None', 'None', 'None', 4, 0, 77, 1, datetime.datetime(2008, 10, 28, 20, 39, 50))
#
# ('umbrant', 33948, 'None', 'andrew@umbrant.com', 'None', 'None', 'None', 33, 4, 94, 4, datetime.datetime(2008, 11, 11, 23, 57, 45))
#
# ('tomwhite', 85085, 'Wales, UK', 'tom.e.white@gmail.com', 'None', 'None', 'None', 205, 3, 921, 2, datetime.datetime(2009, 5, 15, 20, 30, 34))
#
# ('jghoman', 95350, 'Seattle', 'None', 'None', 'None', 'None', 166, 10, 138, 41, datetime.datetime(2009, 6, 14, 21, 30, 3))
#
# ('oza', 104111, 'Tokyo, Japan', 'ozawa.tsuyoshi@gmail.com', 'None', 'None', 'None', 64, 84, 90, 54, datetime.datetime(2009, 7, 12, 11, 50, 13))
#
# ('elicollins', 131502, 'California', 'None', 'None', 'None', 'None', 6, 0, 32, 1, datetime.datetime(2009, 9, 26, 5, 57, 26))
#
# ('cdouglas', 145508, 'None', 'None', 'None', 'None', 'None', 3, 2, 21, 6, datetime.datetime(2009, 10, 27, 21, 46, 30))
#
# ('atm', 148338, 'None', 'None', 'None', 'None', 'atm', 5, 0, 28, 0, datetime.datetime(2009, 11, 3, 15, 19, 34))
#
# ('liuml07', 159186, 'San Francisco Bay Area', 'liuml07@apache.org', 'None', 'Innocent Contributor.', 'liuml07', 9, 10, 128, 62, datetime.datetime(2009, 11, 28, 13, 19, 27))
#
# ('steveloughran', 162090, 'Bristol, England', 'None', 'None', 'Afraid I am not a reviewing any issues/PRs that or not critical. Sorry ', 'None', 53, 13, 449, 2, datetime.datetime(2009, 12, 4, 18, 56, 43))
#
# ('elek', 170549, 'None', 'None', 'True', 'None', 'None', 281, 40, 105, 25, datetime.datetime(2009, 12, 21, 15, 17, 38))
#
# ('sjlee', 197079, 'None', 'None', 'None', 'None', 'None', 15, 4, 31, 0, datetime.datetime(2010, 2, 4, 21, 5, 18))
#
# ('omalley', 206536, 'Sunnyvale, CA', 'omalley@apache.org', 'None', "I'm a software engineer that has been working on big data open source projects since 2006. I'm a PMC member of Hadoop, Hive, and ORC.", 'None', 32, 13, 128, 9, datetime.datetime(2010, 2, 19, 6, 37, 46))
#
# ('cnauroth', 227407, 'Seattle, WA', 'cnauroth@apache.org', 'None', 'Software engineer at Google Cloud Dataproc.  Apache Hadoop PMC member.  ASF member.  The opinions stated here are my own, not necessarily those of my employer.', 'cnauroth', 34, 5, 83, 17, datetime.datetime(2010, 3, 21, 18, 6, 44))
#
# ('acmurthy', 316888, 'None', 'acm@hortonworks.com', 'None', 'None', 'None', 5, 0, 49, 0, datetime.datetime(2010, 6, 28, 22, 18, 22))
#
# ('macroadster', 328366, 'None', 'eric818@gmail.com', 'None', 'None', 'None', 6, 0, 3, 0, datetime.datetime(2010, 7, 10, 17, 18, 31))
#
# ('kihwal', 340000, 'None', 'None', 'None', '@apache Hadoop Committer and a member of Hadoop PMC.\r\nSoftware Engineer at @yahoo.\r\nExtra Class amateur radio operator, a life member of @Arrl.', 'None', 18, 0, 10, 0, datetime.datetime(2010, 7, 21, 18, 9, 50))
#
# ('Jing9', 359132, 'None', 'None', 'None', 'None', 'None', 0, 0, 17, 2, datetime.datetime(2010, 8, 9, 21, 41, 3))
#
# ('vinoduec', 384796, 'None', 'None', 'None', 'None', 'None', 1, 1, 39, 0, datetime.datetime(2010, 9, 2, 7, 32, 46))
#
# ('kambatla', 648114, 'Mountain View, CA', 'None', 'None', 'None', 'None', 15, 0, 20, 4, datetime.datetime(2011, 3, 3, 1, 12, 39))
#
# ('templedf', 651386, 'Palo Alto', 'None', 'None', 'None', 'None', 12, 1, 22, 0, datetime.datetime(2011, 3, 4, 17, 34, 25))
#
# ('sryza', 654855, 'San Francisco', 'sandyryza@gmail.com', 'None', 'None', 's_ryz', 48, 10, 585, 20, datetime.datetime(2011, 3, 7, 3, 31, 41))
#
# ('JunpingDu', 888093, 'SF', 'junping_du@apache.org', 'True', 'Founder of Datastrato', 'None', 37, 0, 217, 8, datetime.datetime(2011, 7, 1, 6, 27, 41))
#
# ('jnp', 903890, 'None', 'None', 'None', 'None', 'None', 11, 0, 2, 1, datetime.datetime(2011, 7, 8, 23, 4, 41))
#
# ('szetszwo', 907380, 'None', 'None', 'None', 'None', 'None', 6, 0, 83, 0, datetime.datetime(2011, 7, 11, 9, 30, 8))
#
# ('szilard-nemeth', 954799, 'Atlanta, GA', 'None', 'None', 'An enthusiastic SW Engineer who loves coding, SW design and tinkering with his projects. True believer of automation. Simple as that.\r\n+Apache Hadoop PMC member', 'szilard_nemeth', 52, 0, 14, 23, datetime.datetime(2011, 8, 2, 18, 36, 40))
#
# ('sborya', 959768, 'None', 'None', 'None', 'None', 'None', 4, 0, 1, 0, datetime.datetime(2011, 8, 4, 19, 27, 33))
#
# ('vivekratnavel', 1051198, 'Santa Clara', 'vivekratnavel90@gmail.com', 'None', 'None', 'None', 26, 1, 28, 6, datetime.datetime(2011, 9, 14, 19, 25, 16))
#
# ('cmccabe', 1095624, 'Sunnyvale, CA', 'colin@cmccabe.xyz', 'None', 'None', 'None', 57, 2, 77, 0, datetime.datetime(2011, 10, 1, 22, 28, 19))
#
# ('flyrain', 1322359, 'None', 'yufei@apache.org', 'None', 'None', 'None', 24, 2, 16, 0, datetime.datetime(2012, 1, 11, 17, 8, 14))
#
# ('jlowe', 1360766, 'Champaign, IL', 'None', 'None', 'None', 'None', 10, 0, 28, 0, datetime.datetime(2012, 1, 20, 22, 15, 1))
#
# ('Hexiaoqiao', 1393756, 'Beijing', 'None', 'None', 'None', 'None', 45, 0, 100, 47, datetime.datetime(2012, 1, 31, 7, 10, 1))
#
# ('umamaheswararao', 1719507, 'Santa Clara, CA, USA', 'umamahesh@apache.org', 'None', 'http://people.apache.org/~umamahesh/umamahesh.html', 'None', 21, 0, 7, 0, datetime.datetime(2012, 5, 8, 20, 21, 50))
#
# ('billierinaldi', 1810597, 'None', 'None', 'None', 'None', 'None', 12, 2, 4, 0, datetime.datetime(2012, 6, 2, 19, 56, 36))
#
# ('sidseth', 1817602, 'None', 'None', 'None', 'None', 'None', 14, 0, 11, 1, datetime.datetime(2012, 6, 5, 2, 9, 17))
#
# ('iwasakims', 1856607, 'None', 'iwasakims@apache.org', 'None', 'None', 'None', 49, 0, 29, 2, datetime.datetime(2012, 6, 16, 12, 3, 54))
#
# ('brahmareddybattula', 1954406, 'Bangalore', 'None', 'None', 'None', 'brahmareddyb', 9, 0, 8, 7, datetime.datetime(2012, 7, 11, 5, 38, 15))
#
# ('subru', 2194334, 'None', 'None', 'None', 'None', 'None', 1, 0, 1, 0, datetime.datetime(2012, 8, 22, 5, 57, 39))
#
# ('arp7', 2480225, 'Santa Clara, California', 'None', 'None', 'None', 'None', 14, 1, 33, 2, datetime.datetime(2012, 10, 3, 15, 51, 33))
#
# ('mingmasplace', 2583464, 'None', 'None', 'None', 'None', 'None', 1, 2, 0, 0, datetime.datetime(2012, 10, 17, 19, 20, 51))
#
# ('jojochuang', 2691807, 'None', 'None', 'None', 'Apache Member. I work on many Apache projects.', 'None', 52, 3, 59, 0, datetime.datetime(2012, 10, 31, 14, 28, 11))
#
# ('hungj', 2773275, 'None', 'jhung@linkedin.com', 'None', 'None', 'None', 9, 0, 10, 0, datetime.datetime(2012, 11, 11, 19, 55, 6))
#
# ('anuengineer', 2831777, 'None', 'None', 'None', 'None', 'None', 22, 0, 19, 3, datetime.datetime(2012, 11, 19, 5, 35, 44))
#
# ('abmodi', 3080594, 'Bangalore', 'abmodi@apache.org', 'None', 'Learning big-data.', 'None', 28, 0, 9, 3, datetime.datetime(2012, 12, 19, 12, 16, 2))
#
# ('xgong', 3181402, 'None', 'None', 'None', 'None', 'None', 14, 0, 3, 1, datetime.datetime(2013, 1, 4, 0, 15, 55))
#
# ('gerashegalov', 3187938, 'San Francisco, CA', 'gera@apache.org', 'None', 'database &amp; ml engineering', 'gerashegalov', 34, 0, 17, 6, datetime.datetime(2013, 1, 4, 19, 14, 6))
#
# ('aajisaka', 3403122, 'Tokyo, Japan', 'None', 'None', 'Software engineer @aws Glue. Apache (@apache) Hadoop/Yetus/Incubator committer and PMC member. Apache Member. I like OSS and distributed systems.', 'ajis_ka', 34, 43, 241, 48, datetime.datetime(2013, 1, 28, 7, 2, 40))
#
# ('revans2', 3441321, 'Champaign IL', 'None', 'None', 'None', 'None', 22, 5, 141, 0, datetime.datetime(2013, 1, 31, 18, 51, 35))
#
# ('rkanter', 3588587, 'None', 'None', 'None', 'None', 'None', 16, 0, 21, 4, datetime.datetime(2013, 2, 13, 22, 6, 12))
#
# ('jian-he', 3662775, 'None', 'None', 'None', 'Now at Alibaba, previously at  Hortonworks.\r\nHadoop Committer &amp; PMC\r\n', 'None', 30, 0, 91, 0, datetime.datetime(2013, 2, 21, 19, 34, 51))
#
# ('haiyang1987', 3760130, 'None', 'huhaiyang926@126.com', 'None', 'None', 'None', 279, 0, 7, 50, datetime.datetime(2013, 3, 4, 2, 41, 45))
#
# ('mukul1987', 4317412, 'Bangalore', 'msingh@confluent.io', 'None', 'None', 'None', 27, 0, 7, 0, datetime.datetime(2013, 5, 2, 3, 23, 25))
#
# ('tgravescs', 4563792, 'None', 'tgraves_cs@yahoo.com', 'None', 'None', 'None', 21, 2, 60, 0, datetime.datetime(2013, 5, 29, 20, 48, 16))
#
# ('virajith', 5614738, 'Sunnyvale, CA', 'None', 'None', 'None', 'None', 0, 0, 2, 0, datetime.datetime(2013, 10, 4, 22, 16, 50))
#
# ('haibchen', 5755773, 'Mountain View', 'None', 'None', 'None', 'None', 5, 0, 10, 8, datetime.datetime(2013, 10, 23, 11, 45, 11))
#
# ('y-liu', 5966204, 'None', 'None', 'None', 'None', 'None', 1, 0, 1, 0, datetime.datetime(2013, 11, 18, 6, 54, 26))
#
# ('jianghuazhu', 6416939, 'HangZhou', '740087514@qq.com', 'None', '《Hadoop HDFS深度剖析与实践》一书作者', 'None', 35, 0, 9, 22, datetime.datetime(2014, 1, 16, 6, 24, 2))
#
# ('adoroszlai', 6454655, 'Hungary', 'None', 'None', 'None', 'None', 83, 0, 36, 0, datetime.datetime(2014, 1, 20, 21, 34, 8))
#
# ('xkrogen', 6570401, 'Bay Area', 'xkrogen@apache.org', 'None', 'None', 'None', 16, 0, 21, 1, datetime.datetime(2014, 2, 2, 22, 48, 21))
#
# ('xiaoyuyao', 7039184, 'None', 'xiaoyuyao@gmail.com', 'None', 'Apache Hadoop PMC and Committer. Working on Open Source Software: Hadoop/HDFS/Ozone.', 'None', 60, 1, 33, 2, datetime.datetime(2014, 3, 23, 15, 42, 25))
#
# ('aw-was-here', 7633626, 'San Jose, CA, USA, Earth, Solar System, Orion-Cygnus Arm, Milky Way', 'aw@apache.org', 'None', 'None', 'None', 24, 0, 18, 0, datetime.datetime(2014, 5, 19, 17, 54, 13))
#
# ('linyiqun', 7877836, 'Shanghai, China', 'None', 'None', 'Apache Hadoop PMC &amp; Apache Ozone PMC, mainly focus on distributed storage. I do believe code can change the world!', 'None', 22, 0, 1033, 10, datetime.datetime(2014, 6, 13, 6, 53, 45))
#
# ('sunilgovind', 7998680, 'None', 'sunilg@apache.org', 'None', 'None', 'None', 5, 0, 16, 3, datetime.datetime(2014, 6, 26, 18, 6, 13))
#
# ('rakeshadr', 8215991, 'Bangalore', 'rakeshr@apache.org', 'None', 'Apache committer &amp; PMC member - Ozone, Hadoop, ZooKeeper, BookKeeper projects. Mainly focussing on distributed storage systems.', 'rakeshadr', 9, 0, 7, 7, datetime.datetime(2014, 7, 20, 13, 43, 33))
#
# ('bharatviswa504', 8586345, 'Canada', 'bharat@apache.org', 'True', 'None', 'None', 37, 0, 9, 4, datetime.datetime(2014, 8, 29, 2, 38, 41))
#
# ('nandakumar131', 8871229, 'Chennai', 'nandakumar131@gmail.com', 'None', 'None', 'None', 16, 0, 16, 0, datetime.datetime(2014, 9, 23, 5, 51, 39))
#
# ('varunsaxena', 10049695, 'Bangalore', 'vasaxena@linkedin.com', 'None', 'Apache Hadoop PMC and Committer, Staff Engineer @ LinkedIn', 'None', 16, 0, 7, 8, datetime.datetime(2014, 12, 2, 16, 24, 27))
#
# ('hanishakoneru', 10237377, 'San Jose, CA', 'None', 'True', 'None', 'None', 7, 0, 1, 0, datetime.datetime(2014, 12, 18, 21, 54, 35))
#
# ('GauthamBanasandra', 10280768, 'Bangalore', 'gautham.bangalore@gmail.com', 'None', 'None', 'None', 58, 17, 32, 6, datetime.datetime(2014, 12, 23, 13, 56, 33))
#
# ('zhe-thoughts', 10713559, 'Sunnyvale, CA, USA', 'zhz@apache.org', 'None', 'Zhe leads the @ray-project Ray.io team at @anyscale ', 'zhz_ray', 17, 0, 85, 141, datetime.datetime(2015, 1, 26, 18, 59, 17))
#
# ('mukund-thakur', 10720944, 'None', 'None', 'None', 'None', 'None', 9, 0, 7, 2, datetime.datetime(2015, 1, 27, 6, 34, 52))
#
# ('tasanuma', 11712443, 'Tokyo, Japan', 'None', 'None', 'Software Engineer, Apache Hadoop Committer', 'None', 14, 1, 23, 12, datetime.datetime(2015, 3, 30, 1, 55, 3))
#
# ('bibinchundatt', 11779290, 'Bangalore', 'bibinchundatt@gmail.com', 'True', 'Apache Hadoop PMC member', 'None', 7, 0, 3, 2, datetime.datetime(2015, 4, 3, 1, 15, 53))
#
# ('pjfanning', 11783444, 'Kilkenny, Ireland', 'None', 'None', 'Experienced developer with an interest in open source. Member of Apache Software Foundation.', 'None', 323, 0, 139, 2, datetime.datetime(2015, 4, 3, 8, 56, 14))
#
# ('shvachko', 11998604, 'San Francisco Bay Area', 'kshvachko@linkedin.com', 'None', 'None', 'None', 2, 3, 12, 0, datetime.datetime(2015, 4, 17, 18, 42, 22))
#
# ('yangwwei', 14214570, 'California', 'wwei@apache.org', 'None', 'AI infra @Apple @apache  @CNCF', 'None', 24, 0, 68, 0, datetime.datetime(2015, 9, 10, 8, 44, 10))
#
# ('xiao-chen', 14279024, 'None', 'None', 'None', 'None', 'None', 17, 2, 15, 11, datetime.datetime(2015, 9, 14, 16, 40, 54))
#
# ('rohithsharmaks', 15336756, 'Atlanta, Georgia', 'rohithsharmaks@apache.org', 'None', 'None', 'rohithsharmaks', 14, 0, 4, 0, datetime.datetime(2015, 10, 27, 5, 12, 35))
#
# ('vinayakumarb', 15498544, 'None', 'vinayakumarb@apache.org', 'None', 'None', 'None', 21, 0, 9, 0, datetime.datetime(2015, 10, 31, 2, 16, 35))
#
# ('ashutoshcipher', 17571497, 'London', 'None', 'None', 'AWS - EMR hadoop and Spark-Perf \r\n', 'None', 20, 0, 8, 16, datetime.datetime(2016, 3, 1, 14, 41, 45))
#
# ('ZanderXu', 17900637, 'beijing', 'xuzq_zander@163.com', 'None', 'None', 'None', 23, 0, 21, 22, datetime.datetime(2016, 3, 17, 9, 22, 59))
#
# ('wangdatan', 20328673, 'Santa Clara', 'wangda@apache.org', 'None', 'Co-Founder of waii.ai. Ex-Snowflake/Cloudera/Alibaba,\r\nApache Hadoop/Submarine/YuniKorn PMC member, ASF Member.', 'None', 8, 0, 48, 0, datetime.datetime(2016, 7, 6, 23, 49, 45))
#
# ('pbacsko', 22025731, 'None', 'None', 'None', 'None', 'None', 7, 0, 3, 1, datetime.datetime(2016, 9, 6, 10, 15, 19))
#
# ('9uapaw', 24417674, 'None', 'None', 'None', 'None', 'None', 15, 0, 5, 7, datetime.datetime(2016, 12, 6, 18, 38, 41))
#
# ('mehakmeet', 25390047, 'None', 'None', 'None', 'Cloud Connectors and Algorithms.', 'None', 35, 0, 11, 7, datetime.datetime(2017, 1, 27, 16, 36, 12))
#
# ('ayushtkn', 25608848, 'India', 'ayushsaxena@apache.org', 'None', 'ASF Member, Apache Hadoop, Hive, Ozone &amp; Incubator PMC Member &amp; Committer, Apache Tez Committer', 'ayuushsaxena', 11, 0, 38, 0, datetime.datetime(2017, 2, 7, 10, 34, 19))
#
# ('bshashikant', 31469764, 'None', 'shashioct19@gmail.com', 'None', 'None', 'None', 4, 0, 2, 0, datetime.datetime(2017, 8, 30, 8, 7, 39))
#
# ('virajjasani', 34790606, 'None', 'None', 'None', 'None', 'None', 16, 0, 17, 0, datetime.datetime(2017, 12, 23, 10, 56, 25))
#
# ('zjshen14', 35021395, 'None', 'None', 'None', 'None', 'None', 20, 13, 25, 6, datetime.datetime(2018, 1, 2, 5, 40, 36))
#
# ('ericbadger', 43999255, 'None', 'None', 'None', 'None', 'None', 0, 0, 0, 0, datetime.datetime(2018, 10, 9, 15, 50, 24))
#
# ('surendralilhore', 45159337, 'None', 'None', 'None', 'None', 'None', 3, 0, 2, 0, datetime.datetime(2018, 11, 19, 5, 26, 48))
#
# ('varun-vasu', 45411708, 'None', 'None', 'None', 'None', 'None', 0, 0, 0, 0, datetime.datetime(2018, 11, 28, 2, 47, 30))
#
# ('smengcl', 50227127, 'Palo Alto, CA', 'None', 'None', 'Software Engineer @ Cloudera / Apache Hadoop Committer / Apache Ozone PMC &amp; Committer / This is a work account :)', 'None', 16, 0, 6, 0, datetime.datetime(2019, 5, 3, 5, 27, 6))
#
# ('naga-apache', 50343640, 'None', 'None', 'None', 'None', 'None', 0, 0, 0, 0, datetime.datetime(2019, 5, 6, 22, 29, 19))
#
# ('amahussein', 50450311, 'None', 'None', 'None', 'None', 'None', 12, 0, 4, 1, datetime.datetime(2019, 5, 9, 12, 23, 42))
#
# ('tomscut', 55134131, 'Singapore', 'tomscut@apache.org', 'None', 'Apache Hadoop Committer &amp; \r\nCNCF CubeFS Committer.\r\nKeep Learning~', 'None', 148, 0, 34, 40, datetime.datetime(2019, 9, 10, 9, 4, 25))
#
# ('slfan1989', 55643692, 'None', 'None', 'None', 'None', 'None', 76, 0, 28, 16, datetime.datetime(2019, 9, 22, 2, 49, 2))
#
# ('erichadoop', 74205577, 'None', 'None', 'None', 'None', 'None', 0, 0, 0, 0, datetime.datetime(2020, 11, 9, 17, 56, 21))
