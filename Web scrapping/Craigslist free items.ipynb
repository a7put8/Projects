# %% [markdown]
# Import necessary libraries

# %%
from bs4 import BeautifulSoup
import time
import requests
import re
import os

# %% [markdown]
# #### Interaction with the Page-Sorting
# - On interacting with the page, it can be observed that yes, we can trigger the sorting change directly by modifying only the URL in browser’s address bar by editing sort = dateoldest
# - On investingating network, it can be observed that sorting my oldest is a GET request
# - The variable associated with sorting is the "sort" variable

# %% [markdown]
# #### Interaction with the Page-Pagination
# - It can be observed that 120 items are dispayed on each page
# - url = "https://sfbay.craigslist.org/search/zip?sort=date#search=1~gallery~0~0"
# - the part of the url that changes when nagigating between pages is the variable seach = 1\~gallery\~0\~0. In value provided to the variable, the following is the format of change when clicked on next page
#     gallery\~"page number"\~0
# - As mentioned above, the variable associated with page changes is the "search" variable in the url. Altering this variables results in:
#     1. Navigation between pages when "number" in 1\~gallery\~"number"\~0 is changed.
#     2. Scroll downward on the same page when the "position" in 1\~gallery\~0\~"position" is changed.

# %%
url = "https://sfbay.craigslist.org/search/zip#search=1~gallery~0~0"
header = {'User-Agent': 'Mozilla/5.0'}
page = requests.get(url, header)
soup = BeautifulSoup(page.content, "html.parser")

# %% [markdown]
# - The links to individual weblinks are housed in the a tags within the "li" tags (list item). i.e the list item houses the target items, and the "a" tag houses the link to the target item.
# - So, i will select the "li" tag then the immediate "a" tag under it

# %%
a_tags = soup.select("li > a")
weblinks1 = [i['href'] for i in a_tags]
#weblinks1

# %% [markdown]
# - An alternative way would be to directly find all the "a" tags with an href and remove the first two links as they are not related to the items of interest

# %%
tags = soup.select("a[href]")
weblinks1 = [j['href'] for i,j in enumerate(tags) if i not in [0,1]]
#weblinks1

# %% [markdown]
# #### Fetch Listing URLs
#
# The strategy to get the listings urls is as follows:
# - Create an empty list to store the urls, create a flag variable, and declare initial page index
# - We need 250 unique listings, in this case we know that each page shows 120 items, but that may not always be the case. Hence, a flag variable will remain false until 250 unique urls are scrapped.
# - A while loop will run until 250 unique urls are collected
# - After each round of page scrapped, we increase page index by one to navigate between pages
# - On each page get the html content and create a beautiful soup instance.
# - Access the "a" tag within the "li" tag. Get the link.
# - Check if list already has 250 items, if yes, set flag to true and stop scrapping, else, check if the link already exists in the list If not, add url to list else continue.

# %%
## Declare variables
weblinks = []  ## Empty list to collect web url of 250 unique listings
flag_items = False ## Declare a flag to run scrapping until 250 unique listing links are captured
page_index = 0  ## Page index for pagination

## Collect links for 250 unique listings
while flag_items == False:

    ## pagination by manipulating url
    url = f"https://sfbay.craigslist.org/search/zip#search=1~gallery~{page_index}~0"
    header = {'User-Agent': 'Mozilla/5.0'}
    page = requests.get(url, header)
    
    ## create BeautifulSoup instance
    soup = BeautifulSoup(page.content, "html.parser")
    
    ## Extract links
    a_tags = soup.select("li > a")
    for i in a_tags:
        link = i['href']
        if len(weblinks) < 250:
            if i['href'] not in weblinks:
                weblinks.append(link)
            else:
                continue
        else:
            flag_items = True
            break
    
    page_index+= 1
    
    time.sleep(5)

## Print links       
weblinks
# Out:
# ['https://sfbay.craigslist.org/eby/zip/d/antioch-free-antique-floor-standing/7714536489.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-twin-size-bed-frame/7714536307.html',
#  'https://sfbay.craigslist.org/scz/zip/d/freedom-ikea-laptop-stand-bed-tray/7714535545.html',
#  'https://sfbay.craigslist.org/eby/zip/d/san-ramon-built-in-counter-depth/7714535179.html',
#  'https://sfbay.craigslist.org/sby/zip/d/milpitas-non-working-chest-freezer/7712074474.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-box-of-breastmilk-storage-bags/7714534032.html',
#  'https://sfbay.craigslist.org/scz/zip/d/freedom-free-computer-monitor/7714533705.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-kid-science-kit-free/7714532990.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-free-pregnancy-pillow/7707497306.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-free-istanbul-metro-card/7706359982.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-free-stuff/7711572302.html',
#  'https://sfbay.craigslist.org/eby/zip/d/pleasant-hill-free-lamps/7714530780.html',
#  'https://sfbay.craigslist.org/eby/zip/d/drafting-stool/7714530054.html',
#  'https://sfbay.craigslist.org/eby/zip/d/hayward-book-ends/7714529989.html',
#  'https://sfbay.craigslist.org/pen/zip/d/san-mateo-hp-color-laserjet-cp1518ni/7714529428.html',
#  'https://sfbay.craigslist.org/eby/zip/d/fremont-chair/7714529410.html',
#  'https://sfbay.craigslist.org/eby/zip/d/castro-valley-free-beautiful-antique/7706573192.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-sinks-free-delivery-monday-am/7714528699.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-walgreens-ultrasonic/7714526026.html',
#  'https://sfbay.craigslist.org/pen/zip/d/palo-alto-bag-of-crayons/7713466445.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-lots-of-good-boxes-for/7714524888.html',
#  'https://sfbay.craigslist.org/eby/zip/d/brentwood-rug/7714523278.html',
#  'https://sfbay.craigslist.org/scz/zip/d/mount-hermon-free-american-standard/7711920009.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-child-guard-plastic-bag/7712999768.html',
#  'https://sfbay.craigslist.org/scz/zip/d/santa-cruz-drafting-table/7714521653.html',
#  'https://sfbay.craigslist.org/nby/zip/d/san-rafael-small-couch/7714520370.html',
#  'https://sfbay.craigslist.org/eby/zip/d/el-sobrante-upper-left-control-arm-350z/7713214831.html',
#  'https://sfbay.craigslist.org/eby/zip/d/el-sobrante-micro-usb-car-charger/7705881682.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-woven-laundry-basket/7714517912.html',
#  'https://sfbay.craigslist.org/pen/zip/d/burlingame-three-picture-frames/7714516914.html',
#  'https://sfbay.craigslist.org/sby/zip/d/sunnyvale-free-cookeare-pots-and-pans/7714516674.html',
#  'https://sfbay.craigslist.org/eby/zip/d/concord-ft-shop-lamp/7709517015.html',
#  'https://sfbay.craigslist.org/scz/zip/d/soquel-oak-chair/7705079606.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-estate-sale-very-big/7714515494.html',
#  'https://sfbay.craigslist.org/sby/zip/d/campbell-desk-with-plenty-of-storage/7714514967.html',
#  'https://sfbay.craigslist.org/nby/zip/d/petaluma-queen-matress/7714514707.html',
#  'https://sfbay.craigslist.org/pen/zip/d/burlingame-chappywrap-blanket/7714514479.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-black-bamboo-stakes/7714513552.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-ikea-kolbjorn-metal/7714513275.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-cherry-wood-bookcase-free/7714512690.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-play-yard-for-kids-or-pets/7714512536.html',
#  'https://sfbay.craigslist.org/eby/zip/d/dublin-rawlings-baseball-helmet/7704690348.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-plastic-champagne/7707544354.html',
#  'https://sfbay.craigslist.org/sby/zip/d/cupertino-medela-pump-in-style-breast/7713192939.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-life-insurance-and/7713051971.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-hair-care-products-deodorant/7714510842.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-animal-medications-for/7713093216.html',
#  'https://sfbay.craigslist.org/pen/zip/d/san-bruno-solid-wood-hutch/7710920531.html',
#  'https://sfbay.craigslist.org/eby/zip/d/pleasanton-free-22-bike-tube/7714508968.html',
#  'https://sfbay.craigslist.org/sby/zip/d/sunnyvale-covid-tests-expired-extended/7714505353.html',
#  'https://sfbay.craigslist.org/eby/zip/d/union-city-co-sleeper-bedside-bassinet/7714508053.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-blender-waring-pro/7714506823.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-little-bench-pending/7714506962.html',
#  'https://sfbay.craigslist.org/sby/zip/d/sunnyvale-chicco-keyfit-car-seat-car/7714506798.html',
#  'https://sfbay.craigslist.org/eby/zip/d/union-city-stroller-cup-holder/7714506573.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-gift-wrapping-paper-bags/7714506486.html',
#  'https://sfbay.craigslist.org/scz/zip/d/aptos-free-clay-dirt-take-as-much-as/7712204736.html',
#  'https://sfbay.craigslist.org/sby/zip/d/los-gatos-free-spalding-54-in/7714505757.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-two-poinsettas/7711761947.html',
#  'https://sfbay.craigslist.org/eby/zip/d/crockett-sturdy-college-loft-bed-and-or/7714505639.html',
#  'https://sfbay.craigslist.org/nby/zip/d/guerneville-box-spring-and-bed-frame/7714504718.html',
#  'https://sfbay.craigslist.org/sby/zip/d/sunnyvale-stapler-rubber-bands-and-hole/7714505411.html',
#  'https://sfbay.craigslist.org/sby/zip/d/campbell-free-hot-tube/7714504538.html',
#  'https://sfbay.craigslist.org/eby/zip/d/hayward-reef-sand/7713797530.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-free-ikea-sektion-pantry-cabinet/7714504211.html',
#  'https://sfbay.craigslist.org/pen/zip/d/san-mateo-fireplace-grate/7712601424.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-laundry-basket-vertical-style/7714503547.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-free-okeefe-merritt-stove/7714500694.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-humidifier-holmes/7713160483.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-costume-paint-and-fake/7713154629.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-free-olive-green-velvet-chair/7714499488.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-navy-blue-pbk-camp-bunk-bed/7714498039.html',
#  'https://sfbay.craigslist.org/pen/zip/d/burlingame-becco-baby-carrier/7714497918.html',
#  'https://sfbay.craigslist.org/eby/zip/d/concord-free-interior-door-hinges/7714497189.html',
#  'https://sfbay.craigslist.org/pen/zip/d/burlingame-ergo-baby-carrier/7714497580.html',
#  'https://sfbay.craigslist.org/pen/zip/d/los-altos-ears-free-headphones/7714497428.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-comfortable-couch-chaise-seats/7714497097.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-tier-storage-shelf/7714496639.html',
#  'https://sfbay.craigslist.org/eby/zip/d/hayward-free-desk/7714495853.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-free-dirt/7710471918.html',
#  'https://sfbay.craigslist.org/eby/zip/d/alameda-free-electronics/7714484558.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-small-plywood-cubby/7714494921.html',
#  'https://sfbay.craigslist.org/pen/zip/d/redwood-city-office-supplies/7712913727.html',
#  'https://sfbay.craigslist.org/nby/zip/d/petaluma-netgear-nighthawk-ac2400/7714494626.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-burner-bikes/7714494027.html',
#  'https://sfbay.craigslist.org/eby/zip/d/martinez-mirror-x-7/7712404017.html',
#  'https://sfbay.craigslist.org/sby/zip/d/saratoga-brass-drawer-knobs/7714493444.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-left-over-farrow-ball/7714492757.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-ikea-sunnersta-rail-rack/7714490559.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-queen-size-headboard/7713768502.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-cuisnart-smart-stick/7714488813.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-singer-sewing-machine-and-table/7714487987.html',
#  'https://sfbay.craigslist.org/nby/zip/d/mill-valley-bronze-chandelier/7714487824.html',
#  'https://sfbay.craigslist.org/nby/zip/d/petaluma-shower-sliding-door-with/7712556912.html',
#  'https://sfbay.craigslist.org/nby/zip/d/petaluma-used-lange-womens-ski-boots/7714487622.html',
#  'https://sfbay.craigslist.org/nby/zip/d/petaluma-sonos-bridge/7714487510.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-glass-shelves-for/7714486949.html',
#  'https://sfbay.craigslist.org/eby/zip/d/antioch-free-dynex-40-inch-1080p-full/7713100999.html',
#  'https://sfbay.craigslist.org/eby/zip/d/antioch-free-big-lot-of-genuine-oem/7711552921.html',
#  'https://sfbay.craigslist.org/pen/zip/d/palo-alto-free-laundry/7714484163.html',
#  'https://sfbay.craigslist.org/nby/zip/d/windsor-free-kimball-piano/7707298671.html',
#  'https://sfbay.craigslist.org/pen/zip/d/san-carlos-daily-contact-lenses/7714483046.html',
#  'https://sfbay.craigslist.org/sby/zip/d/los-altos-ikea-crib-and-gently-used/7714482964.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-vest-vintage/7713822068.html',
#  'https://sfbay.craigslist.org/eby/zip/d/albany-free-standing-outdoor-indoor/7714481911.html',
#  'https://sfbay.craigslist.org/eby/zip/d/richmond-inch-foam-board-weathered/7714481280.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-portable-gas-griddle/7714481213.html',
#  'https://sfbay.craigslist.org/eby/zip/d/dublin-genuine-mwf-refrigerator-water/7714480447.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-garden-pots-drainage/7714480358.html',
#  'https://sfbay.craigslist.org/pen/zip/d/atherton-set-of-arabic-books/7714480230.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-mirror/7714479279.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-cute-small-loveseat/7714479153.html',
#  'https://sfbay.craigslist.org/pen/zip/d/mountain-view-dremel-handheld-battery/7714479047.html',
#  'https://sfbay.craigslist.org/pen/zip/d/redwood-city-king-size-mattress/7714478415.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-fake-chdistmas-tree-vase-mason/7714478223.html',
#  'https://sfbay.craigslist.org/pen/zip/d/atherton-entire-twin-bed-frame-mattress/7714477965.html',
#  'https://sfbay.craigslist.org/pen/zip/d/atherton-free-two-pool-lounge-chairs/7712213645.html',
#  'https://sfbay.craigslist.org/pen/zip/d/atherton-handmade-display-cabinet/7712222572.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-pioneer-elite/7714476032.html',
#  'https://sfbay.craigslist.org/nby/zip/d/larkspur-vitamaster-triumph-treadmill/7711309600.html',
#  'https://sfbay.craigslist.org/sby/zip/d/cupertino-sat-spanish-chemistry-physics/7714475460.html',
#  'https://sfbay.craigslist.org/pen/zip/d/palo-alto-free-styrofoam-cooler/7710966088.html',
#  'https://sfbay.craigslist.org/sby/zip/d/gilroy-small-pots/7714473603.html',
#  'https://sfbay.craigslist.org/pen/zip/d/redwood-city-free-6ft-wood-ladder/7714472622.html',
#  'https://sfbay.craigslist.org/sby/zip/d/sunnyvale-free-broken-color-laser/7714471608.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-blue-sports-field/7714471292.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-shimano-pedals/7714469918.html',
#  'https://sfbay.craigslist.org/pen/zip/d/san-mateo-pending-huggies-pull-ups/7714469025.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-round-bar-table-36-inches/7714468913.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-pending-free-blue-and-white/7714468130.html',
#  'https://sfbay.craigslist.org/scz/zip/d/santa-cruz-work-bench/7714467082.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-leather-ikea-loveseat/7714466615.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-food-containers-qty-37/7710032955.html',
#  'https://sfbay.craigslist.org/pen/zip/d/palo-alto-free-queen-size-box-spring-in/7714465106.html',
#  'https://sfbay.craigslist.org/eby/zip/d/emeryville-king-size-bed-with-wood-frame/7714464967.html',
#  'https://sfbay.craigslist.org/sby/zip/d/gilroy-free-sofas/7714464772.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-painting-canvas-and/7714464485.html',
#  'https://sfbay.craigslist.org/eby/zip/d/pleasant-hill-free-couch/7714464244.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-hot-wheels-super-speed/7714464160.html',
#  'https://sfbay.craigslist.org/sby/zip/d/santa-clara-free-dining-table-and-end/7714463909.html',
#  'https://sfbay.craigslist.org/pen/zip/d/south-san-francisco-love-sofa/7714463790.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-working-treadmill/7713710571.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-upright-piano/7710208630.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-office-desk/7710140691.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-oversized-books-history/7714463160.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-little-tykes-turtle-sandbox/7714462153.html',
#  'https://sfbay.craigslist.org/eby/zip/d/albany-bathroom-cabinet/7714462115.html',
#  'https://sfbay.craigslist.org/nby/zip/d/novato-desk-hutch-or-headboard/7714461656.html',
#  'https://sfbay.craigslist.org/nby/zip/d/novato-desk-hutch/7712015602.html',
#  'https://sfbay.craigslist.org/nby/zip/d/san-rafael-vintage-chair/7714460334.html',
#  'https://sfbay.craigslist.org/pen/zip/d/san-mateo-pedi-pads/7714459423.html',
#  'https://sfbay.craigslist.org/sby/zip/d/sunnyvale-free-tv/7714457485.html',
#  'https://sfbay.craigslist.org/pen/zip/d/daly-city-futon-sofa-couch-bed-pullout/7714457207.html',
#  'https://sfbay.craigslist.org/nby/zip/d/fulton-ford-v8-intake-manifold/7714456919.html',
#  'https://sfbay.craigslist.org/pen/zip/d/pacifica-disposable-male-doggy-wrap/7714456640.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-10g-fish-tank/7714456274.html',
#  'https://sfbay.craigslist.org/pen/zip/d/burlingame-pallet-and-scrap-baseboard/7714454619.html',
#  'https://sfbay.craigslist.org/nby/zip/d/rohnert-park-sofa-and-love-seat/7714453119.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-computer-table/7714452837.html',
#  'https://sfbay.craigslist.org/scz/zip/d/santa-cruz-ikea-queen-bedframe/7714452828.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-garage-foor-opener/7714452593.html',
#  'https://sfbay.craigslist.org/pen/zip/d/daly-city-leather-sofa-couch-loveseat/7714452352.html',
#  'https://sfbay.craigslist.org/scz/zip/d/aptos-free-tinkertoys/7714452278.html',
#  'https://sfbay.craigslist.org/eby/zip/d/concord-metal-drain-cleaner/7714452162.html',
#  'https://sfbay.craigslist.org/eby/zip/d/alameda-brown-wooden-dresser/7714451740.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-wall-mount-bike-rack/7714451449.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-big-gift-bag-for-baby-shower/7709602138.html',
#  'https://sfbay.craigslist.org/scz/zip/d/aptos-free-baby-crib-mattress-never-used/7714450273.html',
#  'https://sfbay.craigslist.org/pen/zip/d/redwood-city-cooler-45-ish-quart/7712477234.html',
#  'https://sfbay.craigslist.org/eby/zip/d/el-cerrito-free-two-used-ikea-kura-beds/7714449096.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-laptop-sleeve/7714449357.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-swap-cooler-evaportavie-cooler/7712143420.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-dorset-sheep-wool-fleeces/7714447995.html',
#  'https://sfbay.craigslist.org/pen/zip/d/redwood-city-free-dresser-drawers/7714447992.html',
#  'https://sfbay.craigslist.org/scz/zip/d/aptos-powder-shakes/7714447950.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-bontrager-helmet-covers/7714447380.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-down-queen-comforter-and-twin/7714447152.html',
#  'https://sfbay.craigslist.org/eby/zip/d/hayward-free-fridge/7714446243.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-cordline-to-cover-and/7714446042.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-free-drop-in-bathtub-available/7714445485.html',
#  'https://sfbay.craigslist.org/nby/zip/d/petaluma-keep-your-stuff-dry-plastic/7714444144.html',
#  'https://sfbay.craigslist.org/nby/zip/d/novato-white-shelves/7714443784.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-tote-bags/7714442942.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-scrap-wood-2x4-studs/7714442491.html',
#  'https://sfbay.craigslist.org/nby/zip/d/petaluma-bag-of-masks-many-colors/7714441108.html',
#  'https://sfbay.craigslist.org/nby/zip/d/petaluma-bike-bags-you-need-to-have/7714440939.html',
#  'https://sfbay.craigslist.org/nby/zip/d/petaluma-blood-gloucose-monitor-system/7714440682.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-free-ceiling-fan-fully/7714439415.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-womens-clothing-good/7714439336.html',
#  'https://sfbay.craigslist.org/eby/zip/d/alameda-la-boy-urban-attitudes-carlyle/7714438251.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-hp-colorjet-2605dn-for-parts/7714437197.html',
#  'https://sfbay.craigslist.org/eby/zip/d/san-leandro-free-wood-etc-from-kitchen/7714437103.html',
#  'https://sfbay.craigslist.org/pen/zip/d/stanford-free-vintage-tack-box-wall/7714437085.html',
#  'https://sfbay.craigslist.org/nby/zip/d/petaluma-bits-and-bobs/7714435921.html',
#  'https://sfbay.craigslist.org/sby/zip/d/sunnyvale-corner-computer-desk/7714435381.html',
#  'https://sfbay.craigslist.org/scz/zip/d/boulder-creek-free-trampoline-10/7714434867.html',
#  'https://sfbay.craigslist.org/nby/zip/d/petaluma-hanger-from-french-line-liberte/7714433430.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-new-medical-convalescent-equip/7714433007.html',
#  'https://sfbay.craigslist.org/eby/zip/d/concord-sugar/7713476050.html',
#  'https://sfbay.craigslist.org/pen/zip/d/san-carlos-hp-laserjet-pro-400-m401/7714432214.html',
#  'https://sfbay.craigslist.org/nby/zip/d/petaluma-vintage-hotel-give-aways/7714432158.html',
#  'https://sfbay.craigslist.org/eby/zip/d/brentwood-wall-clock/7707822463.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-yellow-gari/7714431142.html',
#  'https://sfbay.craigslist.org/eby/zip/d/brentwood-comfy-recliner/7707816009.html',
#  'https://sfbay.craigslist.org/eby/zip/d/brentwood-free-cali-bullets-black-ops/7709834671.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-queen-size-mattress-cover/7714430819.html',
#  'https://sfbay.craigslist.org/nby/zip/d/petaluma-tiny-pill-boxes/7714430250.html',
#  'https://sfbay.craigslist.org/pen/zip/d/san-mateo-free-mahjong-poker-chinese/7714429617.html',
#  'https://sfbay.craigslist.org/eby/zip/d/alameda-free-heater-filters/7714429176.html',
#  'https://sfbay.craigslist.org/nby/zip/d/petaluma-sonoma-county-vintage-visitors/7714428428.html',
#  'https://sfbay.craigslist.org/eby/zip/d/walnut-creek-15-heavy-duty-pallets-free/7714427624.html',
#  'https://sfbay.craigslist.org/eby/zip/d/emeryville-free-baby-things/7714427235.html',
#  'https://sfbay.craigslist.org/sby/zip/d/gilroy-office-desk-cabinets/7709469262.html',
#  'https://sfbay.craigslist.org/eby/zip/d/el-cerrito-mostly-childrens-dvds/7714424146.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-free-on-curb-double-pane-window/7714423952.html',
#  'https://sfbay.craigslist.org/scz/zip/d/redwood-estates-coffee-table-side-piece/7714423059.html',
#  'https://sfbay.craigslist.org/nby/zip/d/santa-rosa-55-gallon-drums/7712789601.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-queen-aerobed-air/7713089936.html',
#  'https://sfbay.craigslist.org/nby/zip/d/sausalito-bike-rack-for-car/7714421513.html',
#  'https://sfbay.craigslist.org/sby/zip/d/santa-clara-lamp/7714420130.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-step-stool-water-cube/7714421201.html',
#  'https://sfbay.craigslist.org/sby/zip/d/santa-clara-wooden-chairs/7714420998.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-car-audio-ground-loop-noise/7714419996.html',
#  'https://sfbay.craigslist.org/scz/zip/d/freedom-wood-desk/7714419923.html',
#  'https://sfbay.craigslist.org/pen/zip/d/redwood-city-commercial-and-household/7714415886.html',
#  'https://sfbay.craigslist.org/eby/zip/d/martinez-free-flower-vases/7714414681.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-canopy-awnings/7712840470.html',
#  'https://sfbay.craigslist.org/pen/zip/d/palo-alto-free-5x7-wool-rug/7714412364.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-nespresso-citiz/7714412252.html',
#  'https://sfbay.craigslist.org/nby/zip/d/vineburg-free-canvas-hanging-wardrobe/7709573729.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-farmhouse-style-hutch/7714412081.html',
#  'https://sfbay.craigslist.org/pen/zip/d/palo-alto-free-8x10-wool-rug/7714411641.html',
#  'https://sfbay.craigslist.org/nby/zip/d/novato-baby-jogger-stroller-adaptor-for/7714411585.html',
#  'https://sfbay.craigslist.org/eby/zip/d/fremont-recessed-lighting-hardware-and/7714411128.html',
#  'https://sfbay.craigslist.org/pen/zip/d/redwood-city-queen-headboard/7714410406.html',
#  'https://sfbay.craigslist.org/nby/zip/d/santa-rosa-chair-broken-stool-plastic/7714409180.html',
#  'https://sfbay.craigslist.org/eby/zip/d/fremont-led-bulbs-two-kinds/7707225563.html',
#  'https://sfbay.craigslist.org/eby/zip/d/fremont-ricoh-aficio-2027sp/7714407703.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-mens-tommaso-shoes-size-14/7714406723.html',
#  'https://sfbay.craigslist.org/eby/zip/d/hayward-free-small-desk/7714406419.html',
#  'https://sfbay.craigslist.org/nby/zip/d/novato-free-toaster-oven/7714405077.html',
#  'https://sfbay.craigslist.org/pen/zip/d/san-mateo-free-diy-twin-daybed-storage/7714404562.html',
#  'https://sfbay.craigslist.org/eby/zip/d/concord-2006-tundra-driver-door/7714404789.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-navy-size-comfy-slippers/7714404664.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-medela-breast-pump/7712107626.html',
#  'https://sfbay.craigslist.org/nby/zip/d/larkspur-scrap-wood/7713476676.html',
#  'https://sfbay.craigslist.org/nby/zip/d/larkspur-hot-wheels-garage/7711839982.html',
#  'https://sfbay.craigslist.org/nby/zip/d/larkspur-rigid-ducting/7711841162.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-womens-clarks-navy-wedges/7714403656.html',
#  'https://sfbay.craigslist.org/nby/zip/d/petaluma-sawdust-stuffed-horse-vintage/7714403401.html']

# %%
len(weblinks)
# Out:
# 250

# %% [markdown]
# #### Save HTML Pages

# %% [markdown]
# - Using library os to create a new directory to save the listings' page information
# - Split the url and get the last string as name of the document as it identifies the listing id

# %%
## Create new directory named 'listings'
output_dir = 'listings'
os.makedirs(output_dir, exist_ok=True)

for i in weblinks:
    
    url = i
    page = requests.get(url)

    filename = os.path.join(output_dir, f'{i.split("/")[-1]}')  ## Save file name using the last string sequence in url

    with open(filename, 'w', encoding='utf-8') as file:
    
        file.write(page.text)

        time.sleep(5)

# %% [markdown]
# - Find the .html files in the new directory.
# - Loop through the directory and create a BeautifulSoup instance of each listing's html page
# - Use regex to find the required information and print to screen

# %%
## Access new directory
directory_path = 'listings'

for filename in os.listdir(directory_path):
    if filename.endswith('.html'): ## Check for .html files
        file_path = os.path.join(directory_path, filename)
        
        with open(file_path, 'r', encoding='utf-8') as file:
            html_content = file.read()
            soup = BeautifulSoup(html_content, 'html.parser') ## Create BeautifulSoup instance
            
            ## Use regex to find required information
            if soup.find('span', {'id': 'titletextonly'}) is not None:
                title = soup.find('span', {'id': 'titletextonly'}).next
                
                if soup.find('img') is not None:

                    img_url = soup.find('img')['src']
                
                else:

                    img_url = "Image unavailable"

                desc_string = str(soup.find('section', {"id" : "postingbody"}))

                description = re.findall(r"\n([^<]+)<", desc_string)[0]

                pattern_id = re.compile("post id: ")
                post_id = re.findall(": (\d+)" ,soup.find_all(string=pattern_id)[0])[0]

                pattern_post = re.compile('posted:')
                posted_date = re.findall(r">([^<]+)</" ,str(soup.find(string = pattern_post).parent))[0]

                pattern = re.compile('updated')

                if soup.find(string = pattern) is not None:

                    update_date = re.findall(r">([^<]+)</" ,str(soup.find(string = pattern).parent))[0]

                else:
                    
                    update_date = "Last updated date not available"  
                
                #print(f"Post ID : {post_id}", "\n")
                print(f"Title : {title}\n")
                print(f"URL of first image : {img_url}\n")
                print(f"Description : {description}\n")
                print(f"Post ID : {post_id}", "\n")
                print(f"Posted Date : {posted_date}\n")
                print(f"Last Updated Date : {update_date}\n")
                print("*************************************************************************************************")
                
            else:
                print("Posting deleted")
                continue
# Out:
# Title : Rawlings baseball helmet 6 1/4-6 7/8
#
# URL of first image : https://images.craigslist.org/00p0p_hZSMbBjPoJT_0tE0CI_600x450.jpg
#
# Description : Used two seasons in little league
#
# Post ID : 7704690348
#
# Posted Date : 2024-01-05 19:19
#
# Last Updated Date : 2024-02-04 17:35
#
# *************************************************************************************************
# Title : Oak chair
#
# URL of first image : https://images.craigslist.org/00n0n_baDAS4segUc_0t20CI_600x450.jpg
#
# Description : Swivels, height adjusts, great condition
#
# Post ID : 7705079606
#
# Posted Date : 2024-01-07 06:58
#
# Last Updated Date : 2024-02-04 17:51
#
# *************************************************************************************************
# Title : Micro USB Car Charger
#
# URL of first image : https://images.craigslist.org/00v0v_coblI9aG3YU_0t20CI_600x450.jpg
#
# Description : Don't need this
#
# Post ID : 7705881682
#
# Posted Date : 2024-01-09 12:45
#
# Last Updated Date : 2024-02-04 18:09
#
# *************************************************************************************************
# Title : FREE Istanbul Metro Card
#
# URL of first image : https://images.craigslist.org/00h0h_lM7qn9s6Spm_0t20CI_600x450.jpg
#
# Description : Might be some money left on it, not sure.
#
# Post ID : 7706359982
#
# Posted Date : 2024-01-10 22:00
#
# Last Updated Date : 2024-02-04 19:20
#
# *************************************************************************************************
# Title : Free beautiful antique twin bed frame
#
# URL of first image : https://images.craigslist.org/00J0J_anTNI7LgRnq_0CI0t9_600x450.jpg
#
# Description : Free.  Really nice, beautiful wood antique bed frame.  Free to the first person who can pick it up
#
# Post ID : 7706573192
#
# Posted Date : 2024-01-11 12:54
#
# Last Updated Date : 2024-02-04 19:07
#
# *************************************************************************************************
# Title : LED Bulbs (two kinds)
#
# URL of first image : https://images.craigslist.org/00q0q_9Zlcx6ZGSZy_0CI0lM_600x450.jpg
#
# Description : 2x KAILIN 2700K 800lm
#
# Post ID : 7707225563
#
# Posted Date : 2024-01-13 12:06
#
# Last Updated Date : 2024-02-04 11:53
#
# *************************************************************************************************
# Title : free kimball piano
#
# URL of first image : Image unavailable
#
# Description : One front leg is missing the wheel but can be replaced and is stable without this.
#
# Post ID : 7707298671
#
# Posted Date : 2024-01-13 15:55
#
# Last Updated Date : 2024-02-04 15:41
#
# *************************************************************************************************
# Title : Free pregnancy pillow
#
# URL of first image : https://images.craigslist.org/01414_eAyaugOCcjG_1320MM_600x450.jpg
#
# Description : U shaped, worked great for me. https://www.amazon.com/gp/product/B09LQWCJMG/ref=ppx_yo_dt_b_search_asin_title?ie=UTF8&amp;psc=1
#
# Post ID : 7707497306
#
# Posted Date : 2024-01-14 11:45
#
# Last Updated Date : 2024-02-04 19:20
#
# *************************************************************************************************
# Title : Free plastic champagne flutes
#
# URL of first image : https://images.craigslist.org/00O0O_7kF84lEizn6_0t20CI_600x450.jpg
#
# Description : Heavyweight plastic, one piece plastic champagne flutes. 10 pieces.
#
# Post ID : 7707544354
#
# Posted Date : 2024-01-14 14:14
#
# Last Updated Date : 2024-02-04 17:34
#
# *************************************************************************************************
# Title : Comfy recliner
#
# URL of first image : https://images.craigslist.org/00303_b6yHi33qoUZ_0t20CI_600x450.jpg
#
# Description : Very comfy recliner chai. Cozy and soft, an old fav here that is being replaced. Reclines and is in good condition. Wait till you sit in it.
#
# Post ID : 7707816009
#
# Posted Date : 2024-01-15 11:38
#
# Last Updated Date : 2024-02-04 12:55
#
# *************************************************************************************************
# Title : Wall clock
#
# URL of first image : https://images.craigslist.org/00S0S_jHeu8M8advW_0t20CI_600x450.jpg
#
# Description : Free wall clock
#
# Post ID : 7707822463
#
# Posted Date : 2024-01-15 11:53
#
# Last Updated Date : 2024-02-04 12:55
#
# *************************************************************************************************
# Title : Office desk w/ cabinets
#
# URL of first image : https://images.craigslist.org/00u0u_5DmmHmriyCd_0CI0t2_600x450.jpg
#
# Description : Cherry wood solid office desk
#
# Post ID : 7709469262
#
# Posted Date : 2024-01-20 09:59
#
# Last Updated Date : 2024-02-04 12:39
#
# *************************************************************************************************
# Title : 4 ft shop lamp
#
# URL of first image : https://images.craigslist.org/00z0z_4mGrtisXYgS_0CI0l6_600x450.jpg
#
# Description : Light works but after about 30 minute, it shuts off for 5 to 10 minutes, then the light turns back on
#
# Post ID : 7709517015
#
# Posted Date : 2024-01-20 11:47
#
# Last Updated Date : 2024-02-04 17:54
#
# *************************************************************************************************
# Title : FREE Canvas Hanging Wardrobe, Clothes Storage
#
# URL of first image : https://images.craigslist.org/00808_lP2DM5lzGcw_0dy0t2_600x450.jpg
#
# Description : Keep your clothes clean and dust and moth free between seasons or in storage.
#
# Post ID : 7709573729
#
# Posted Date : 2024-01-20 14:22
#
# Last Updated Date : 2024-02-04 12:01
#
# *************************************************************************************************
# Title : Big gift bag for baby shower
#
# URL of first image : https://images.craigslist.org/00F0F_lumGNxL1WgA_0t20CI_600x450.jpg
#
# Description : Extra large gift bag for a baby shower gift, 24x17x12 inches
#
# Post ID : 7709602138
#
# Posted Date : 2024-01-20 16:04
#
# Last Updated Date : 2024-02-04 13:52
#
# *************************************************************************************************
# Title : Free Cali Bullets Black Ops backpack
#
# URL of first image : https://images.craigslist.org/00x0x_kZd6Y5aieYb_0t20CI_600x450.jpg
#
# Description : My daughter was on Cali black Ops the last three years and collected a few back packs.
#
# Post ID : 7709834671
#
# Posted Date : 2024-01-21 13:08
#
# Last Updated Date : 2024-02-04 12:55
#
# *************************************************************************************************
# Title : Food containers - qty 37, various sizes
#
# URL of first image : https://images.craigslist.org/00h0h_fUriRMgKLrK_0CI0t2_600x450.jpg
#
# Description : See photo. All containers have lids.
#
# Post ID : 7710032955
#
# Posted Date : 2024-01-22 08:14
#
# Last Updated Date : 2024-02-04 14:42
#
# *************************************************************************************************
# Title : Office desk
#
# URL of first image : https://images.craigslist.org/00A0A_f8gCM4G8gZ2_09A08d_600x450.jpg
#
# Description : rough measurements: 72"W x 26"D x 29"H
#
# Post ID : 7710140691
#
# Posted Date : 2024-01-22 12:02
#
# Last Updated Date : 2024-02-04 14:32
#
# *************************************************************************************************
# Title : Upright Piano
#
# URL of first image : https://images.craigslist.org/00Z0Z_4HKmOjjy5q3_0CI0t2_600x450.jpg
#
# Description : hasn't been tuned in over 40 years, but it sounds amazing still
#
# Post ID : 7710208630
#
# Posted Date : 2024-01-22 15:01
#
# Last Updated Date : 2024-02-04 14:32
#
# *************************************************************************************************
# Title : Free Dirt
#
# URL of first image : https://images.craigslist.org/00E0E_kmiTzHgDnC0_0lM0t2_600x450.jpg
#
# Description : More dirt than what is shown in the picture. Must bring your own buckets or soil bags. Coordinated pick up in South Berkeley. Available until Thursday 2/8
#
# Post ID : 7710471918
#
# Posted Date : 2024-01-23 11:28
#
# Last Updated Date : 2024-02-04 16:26
#
# *************************************************************************************************
# Title : Solid Wood Hutch
#
# URL of first image : https://images.craigslist.org/00505_4KRCh6VREfe_0CI0t2_600x450.jpg
#
# Description : Beautiful solid wood hutch
#
# Post ID : 7710920531
#
# Posted Date : 2024-01-24 16:06
#
# Last Updated Date : 2024-02-04 17:20
#
# *************************************************************************************************
# Title : Free Styrofoam Cooler
#
# URL of first image : https://images.craigslist.org/00C0C_9aviIduqqqy_0cX0cb_600x450.jpg
#
# Description : Text for fastest response. If listing is still up they are still available.
#
# Post ID : 7710966088
#
# Posted Date : 2024-01-24 19:33
#
# Last Updated Date : 2024-02-04 15:10
#
# *************************************************************************************************
# Title : Vitamaster Triumph Treadmill
#
# URL of first image : https://images.craigslist.org/00B0B_6z2E2YqIFz5_0t20CI_600x450.jpg
#
# Description : Older model but still works fine.  Inclines up to 15 degrees.
#
# Post ID : 7711309600
#
# Posted Date : 2024-01-25 20:01
#
# Last Updated Date : 2024-02-04 15:13
#
# *************************************************************************************************
# Title : Free Big Lot Of Genuine OEM Dell PowerEdge R620 Server Spare Parts
#
# URL of first image : https://images.craigslist.org/00R0R_dU8YAxYunsA_0CD0t2_600x450.jpg
#
# Description : This listing is for a Free Big Lot Of Genuine OEM Dell PowerEdge R620 Server Spare Parts in the images shown. These parts are for use with Dell PowerEdge R620 servers. They were stored in a IT closet. The parts all appear to be in good condition but they are untested as I don't have a PowerEdge R620 available to test them.
#
# Post ID : 7711552921
#
# Posted Date : 2024-01-26 13:34
#
# Last Updated Date : 2024-02-04 15:48
#
# *************************************************************************************************
# Title : Free Stuff
#
# URL of first image : https://images.craigslist.org/00W0W_dEPi7rnJAY5_0CI0t2_600x450.jpg
#
# Description : Random free stuff!
#
# Post ID : 7711572302
#
# Posted Date : 2024-01-26 14:29
#
# Last Updated Date : 2024-02-04 19:20
#
# *************************************************************************************************
# Title : Two Poinsettas
#
# URL of first image : https://images.craigslist.org/00B0B_6ofUzb7x4yt_0MM132_600x450.jpg
#
# Description : I have two pointsettas from the Christmas season.  I have kept them indoors, but they are slowly losing their leaves.  I am willing to give them to someone who can better care for them.  They are about 2 to 2 1/2 feet tall.
#
# Post ID : 7711761947
#
# Posted Date : 2024-01-27 08:52
#
# Last Updated Date : 2024-02-04 17:05
#
# *************************************************************************************************
# Title : Hot Wheels garage
#
# URL of first image : https://images.craigslist.org/00u0u_ghYuQpYFqtD_0lM0CI_600x450.jpg
#
# Description : Hot Wheels garage. A little dirty since it was played outside. Might be missing the smaller parts but my kid had hours of fun playing with it
#
# Post ID : 7711839982
#
# Posted Date : 2024-01-27 11:59
#
# Last Updated Date : 2024-02-04 11:37
#
# *************************************************************************************************
# Title : 6" rigid ducting
#
# URL of first image : https://images.craigslist.org/01616_8vjUtmIl5k8_0lM0CI_600x450.jpg
#
# Description : Couple 90 degree elbows and extension pieces left over from rerouting a duct
#
# Post ID : 7711841162
#
# Posted Date : 2024-01-27 12:02
#
# Last Updated Date : 2024-02-04 11:37
#
# *************************************************************************************************
# Title : FREE American Standard Toilet
#
# URL of first image : https://images.craigslist.org/01515_qBgHChNwuH_07K0ak_600x450.jpg
#
# Description : We have an American Standard Champion series toilet to give away.
#
# Post ID : 7711920009
#
# Posted Date : 2024-01-27 16:12
#
# Last Updated Date : 2024-02-04 18:31
#
# *************************************************************************************************
# Title : Desk hutch
#
# URL of first image : https://images.craigslist.org/01212_1saoQwBgc9e_0t20CI_600x450.jpg
#
# Description : Desk hutch
#
# Post ID : 7712015602
#
# Posted Date : 2024-01-28 06:36
#
# Last Updated Date : 2024-02-04 14:26
#
# *************************************************************************************************
# Title : Non working chest freezer
#
# URL of first image : https://images.craigslist.org/00D0D_bb0FOETletO_0CI0t2_600x450.jpg
#
# Description : Hisense 7.0 cu ft. It's about 5 years old. Just stopped. Yours for free, if you're handy, it's probably the relay or the thermostat that conked out. I don't have the time to troubleshoot.
#
# Post ID : 7712074474
#
# Posted Date : 2024-01-28 09:51
#
# Last Updated Date : 2024-02-04 19:45
#
# *************************************************************************************************
# Title : Medela Breast Pump
#
# URL of first image : Image unavailable
#
# Description : Almost new Medela Pump In Style Double electric breast pump. Used only a couple times. Can buy new breast shields on Amazon is needed.
#
# Post ID : 7712107626
#
# Posted Date : 2024-01-28 11:29
#
# Last Updated Date : 2024-02-04 11:40
#
# *************************************************************************************************
# Title : Swap cooler / Evaportavie Cooler Pads  - Free
#
# URL of first image : https://images.craigslist.org/00a0a_6NtCiN9OSIo_0cj0q0_600x450.jpg
#
# Description : Swap cooler / Evaportavie Cooler Pads Replacement - Free. Description on pic.
#
# Post ID : 7712143420
#
# Posted Date : 2024-01-28 13:14
#
# Last Updated Date : 2024-02-04 13:45
#
# *************************************************************************************************
# Title : Free clay dirt, take as much as you want!
#
# URL of first image : https://images.craigslist.org/01111_8f7M0tmHTwb_0CI0A5_600x450.jpg
#
# Description : I have multiple cubic yards of free clay dirt ready for you to come pick up and take home with you. If you have a bobcat, you can scoop up as much as you would like.
#
# Post ID : 7712204736
#
# Posted Date : 2024-01-28 17:14
#
# Last Updated Date : 2024-02-04 17:08
#
# *************************************************************************************************
# Title : Free two pool lounge chairs & table
#
# URL of first image : https://images.craigslist.org/00S0S_i7TVBnn3E0e_0CI0t2_600x450.jpg
#
# Description : Recently power washed and in good shape.
#
# Post ID : 7712213645
#
# Posted Date : 2024-01-28 17:58
#
# Last Updated Date : 2024-02-04 15:14
#
# *************************************************************************************************
# Title : Handmade Display Cabinet
#
# URL of first image : https://images.craigslist.org/00u0u_lVp5KrQIQh6_0t20CI_600x450.jpg
#
# Description : Handmade by artisans in Brazil or Ecuador in the late 60s or early 70s (parents living/working abroad at the time and can’t remember exactly when/where they got it). The craftsmanship is incredible. In excellent shape as it was only used as a display and storage cabinet in a formal dining room. Comes with some detached wheels that we are not sure if they belong with the cabinet, but figure we should include them in case.
#
# Post ID : 7712222572
#
# Posted Date : 2024-01-28 18:49
#
# Last Updated Date : 2024-02-04 15:31
#
# *************************************************************************************************
# Title : Mirror 5' x 3’ 7”
#
# URL of first image : https://images.craigslist.org/00J0J_3fIh7sP7AV1_0CI0t2_600x450.jpg
#
# Description : Taken down from bathroom in remodel. Some water spots on very bottom 1/2" but can be covered up or cut off.  Otherwise great shape.
#
# Post ID : 7712404017
#
# Posted Date : 2024-01-29 10:35
#
# Last Updated Date : 2024-02-04 16:18
#
# *************************************************************************************************
# Title : Cooler (45-ish quart capacity)
#
# URL of first image : https://images.craigslist.org/00s0s_ctEHEriuLFy_0Cz0t2_600x450.jpg
#
# Description : Free cooler with wheels. I think it has ~45 quart capacity as the internal space looks about the same as my new cooler. This cooler works and will get the job done but it is old/used. There is a crack in the casing where the handle attaches (see attached picture). Let me know if you are interested and I can provide the pickup address.
#
# Post ID : 7712477234
#
# Posted Date : 2024-01-29 13:27
#
# Last Updated Date : 2024-02-04 13:50
#
# *************************************************************************************************
# Title : Shower sliding door with hardware
#
# URL of first image : https://images.craigslist.org/00303_f9kFpFuEpxx_0lM0CI_600x450.jpg
#
# Description : Removed our bath’s sliding shower door. It has two textured glass doors, a bottom rail, a top rail, and two side rails. 58.25” wide total. Each door is 29.25” X 55.5”.
#
# Post ID : 7712556912
#
# Posted Date : 2024-01-29 17:57
#
# Last Updated Date : 2024-02-04 15:56
#
# *************************************************************************************************
# Title : Fireplace grate
#
# URL of first image : https://images.craigslist.org/00O0O_h8i3cL3Nboa_0t20CI_600x450.jpg
#
# Description : fireplace grate.  24in front X 22in back X 6in high.  Heavy duty, won’t warp or twist in a hot fire.  Have yourself a fire in your fireplace
#
# Post ID : 7712601424
#
# Posted Date : 2024-01-30 00:00
#
# Last Updated Date : 2024-02-04 16:57
#
# *************************************************************************************************
# Title : 55 Gallon Drums
#
# URL of first image : Image unavailable
#
# Description : 55 gallon drums for free they have been triple rinsed and washed out
#
# Post ID : 7712789601
#
# Posted Date : 2024-01-30 12:19
#
# Last Updated Date : 2024-02-04 12:31
#
# *************************************************************************************************
# Title : Free canopy/awnings
#
# URL of first image : https://images.craigslist.org/00w0w_9XGdJ6dw8rm_0jm0pO_600x450.jpg
#
# Description : Free canopies/ awnings
#
# Post ID : 7712840470
#
# Posted Date : 2024-01-30 14:38
#
# Last Updated Date : 2024-02-04 12:04
#
# *************************************************************************************************
# Title : Office Supplies
#
# URL of first image : https://images.craigslist.org/00g0g_6aN2cgLtCKP_0x20oM_600x450.jpg
#
# Description : Colllection of office supplies, paper, folders, notepads, hardbound notebooks, printer paper, binders, paper trays, file folder holders, pens, mechanical pencils.
#
# Post ID : 7712913727
#
# Posted Date : 2024-01-30 19:40
#
# Last Updated Date : 2024-02-04 16:21
#
# *************************************************************************************************
# Title : “Child Guard” Plastic Bag and Canister for Medications
#
# URL of first image : https://images.craigslist.org/00m0m_1IjCvWAIC9V_0ak07K_600x450.jpg
#
# Description : To protect your children and / or pets. You probably need this. Medications NOT included lol.
#
# Post ID : 7712999768
#
# Posted Date : 2024-01-31 07:29
#
# Last Updated Date : 2024-02-04 18:31
#
# *************************************************************************************************
# Title : Life Insurance and Financial Planning Textbooks
#
# URL of first image : https://images.craigslist.org/00m0m_jBtzSYR5g76_0ak07K_600x450.jpg
#
# Description : Life Insurance books (American College) 2005
#
# Post ID : 7713051971
#
# Posted Date : 2024-01-31 09:35
#
# Last Updated Date : 2024-02-04 17:27
#
# *************************************************************************************************
# Title : Queen aerobed air mattress with small leak
#
# URL of first image : https://images.craigslist.org/00L0L_5pZPCfeEsj2_0t20CI_600x450.jpg
#
# Description : Queen size aerobed air mattress. Has a small leak that I couldn't find. Has a built in electric pump so you can just press the button to inflate it more if I gets a bit flat. Free pickup at potrero ave and Mariposa St.
#
# Post ID : 7713089936
#
# Posted Date : 2024-01-31 11:04
#
# Last Updated Date : 2024-02-04 12:29
#
# *************************************************************************************************
# Title : Animal Medications (for small dog under 10 lbs)
#
# URL of first image : Image unavailable
#
# Description : My 8 lb Chihuahua was quite ill at the end of his life before he passed late last year and I know how pricey medications can be. Hopefully these can be repurposed. Note they are in container sthat might claim past due, this is simply because I was resusing containers. That said they may be 3-6 months past their expiration.
#
# Post ID : 7713093216
#
# Posted Date : 2024-01-31 11:12
#
# Last Updated Date : 2024-02-04 17:27
#
# *************************************************************************************************
# Title : Free Dynex 40 Inch 1080p Full HD LCD TV With Remote
#
# URL of first image : https://images.craigslist.org/00101_TzNYidMlBt_0CI0t2_600x450.jpg
#
# Description : I am giving away the Free Dynex 40 Inch 1080p Full HD LCD TV With Remote in the images shown. The TV works and is functional. However, it does have a line of dead pixels down the right side as you can see. This does not affect usability but it is obviously noticeable.
#
# Post ID : 7713100999
#
# Posted Date : 2024-01-31 11:31
#
# Last Updated Date : 2024-02-04 15:48
#
# *************************************************************************************************
# Title : Costume Paint and Fake Blood
#
# URL of first image : https://images.craigslist.org/00p0p_9BTnFtuoqYU_0CI0t2_600x450.jpg
#
# Description : Free costume paint and fake blood including a tub of vaseline to help with the latex paint.
#
# Post ID : 7713154629
#
# Posted Date : 2024-01-31 13:52
#
# Last Updated Date : 2024-02-04 16:43
#
# *************************************************************************************************
# Title : Humidifier - Holmes
#
# URL of first image : https://images.craigslist.org/00505_jEcG8obzvX8_0CI0t2_600x450.jpg
#
# Description : Free working Holmes humidifer.  As seen in the picture there is a broken plastic piece; however, some super glue should easily fix it.
#
# Post ID : 7713160483
#
# Posted Date : 2024-01-31 14:08
#
# Last Updated Date : 2024-02-04 16:43
#
# *************************************************************************************************
# Title : Medela Pump in Style Breast Pump
#
# URL of first image : https://images.craigslist.org/00I0I_etnuCK104LT_0t20CI_600x450.jpg
#
# Description : Medela Pump in Style breast pump
#
# Post ID : 7713192939
#
# Posted Date : 2024-01-31 15:56
#
# Last Updated Date : 2024-02-04 17:33
#
# *************************************************************************************************
# Title : Upper Left Control Arm 350z
#
# URL of first image : https://images.craigslist.org/00Y0Y_jFOyE0XQN11_0CI0t2_600x450.jpg
#
# Description : Getting rid of this extra control arm.
#
# Post ID : 7713214831
#
# Posted Date : 2024-01-31 17:16
#
# Last Updated Date : 2024-02-04 18:09
#
# *************************************************************************************************
# Title : Bag of crayons
#
# URL of first image : https://images.craigslist.org/00d0d_lrGG2yC0azo_0MM132_600x450.jpg
#
# Description : Bag of crayons
#
# Post ID : 7713466445
#
# Posted Date : 2024-02-01 13:03
#
# Last Updated Date : 2024-02-04 18:47
#
# *************************************************************************************************
# Title : Sugar
#
# URL of first image : https://images.craigslist.org/00T0T_6UdQTf6FfP1_0CI0t2_600x450.jpg
#
# Description : (New/Unopened) 1 lb. Bag of Powdered Sugar  -  Exp. Apr. 28, '25
#
# Post ID : 7713476050
#
# Posted Date : 2024-02-01 13:25
#
# Last Updated Date : 2024-02-04 13:00
#
# *************************************************************************************************
# Title : Scrap wood
#
# URL of first image : https://images.craigslist.org/00y0y_bnCOucr8upp_0CI0t9_600x450.jpg
#
# Description : Few 1x8s in various lengths (one or two roughly 12ft long), old broken desk and drawers. Top is solid.  Must take all.
#
# Post ID : 7713476676
#
# Posted Date : 2024-02-01 13:27
#
# Last Updated Date : 2024-02-04 11:38
#
# *************************************************************************************************
# Title : Working treadmill
#
# URL of first image : https://images.craigslist.org/00v0v_kDH9hJRw6SV_0t20CI_600x450.jpg
#
# Description : Downsizing it’s a great machine
#
# Post ID : 7713710571
#
# Posted Date : 2024-02-02 09:17
#
# Last Updated Date : 2024-02-04 14:32
#
# *************************************************************************************************
# Title : Queen Size Headboard
#
# URL of first image : https://images.craigslist.org/00V0V_87k3KtLymlf_0CI0sb_600x450.jpg
#
# Description : On sidewalk near 811 York
#
# Post ID : 7713768502
#
# Posted Date : 2024-02-02 11:25
#
# Last Updated Date : 2024-02-04 16:06
#
# *************************************************************************************************
# Title : reef sand
#
# URL of first image : Image unavailable
#
# Description : aragonite reef sand
#
# Post ID : 7713797530
#
# Posted Date : 2024-02-02 12:31
#
# Last Updated Date : 2024-02-04 17:01
#
# *************************************************************************************************
# Title : Vest, Vintage
#
# URL of first image : https://images.craigslist.org/01111_4BOK3cgbXer_0hq0bC_600x450.jpg
#
# Description : Made in India. 100% cotton, decorated with beads and sequins on black and pink front, solid black satin back.
#
# Post ID : 7713822068
#
# Posted Date : 2024-02-02 13:31
#
# Last Updated Date : 2024-02-04 15:36
#
# *************************************************************************************************
# Title : Sawdust Stuffed Horse (vintage toy)
#
# URL of first image : https://images.craigslist.org/00h0h_cLgtGIAD4vx_0t20CI_600x450.jpg
#
# Description : Sawdust Stuffed Horse
#
# Post ID : 7714403401
#
# Posted Date : 2024-02-04 11:37
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Women’s Clarks Navy Wedges with laces (size 8)
#
# URL of first image : https://images.craigslist.org/00d0d_k6Lj5hAKeCJ_0t20CI_600x450.jpg
#
# Description : Giving away these adorable Navy Clark’s wedges size 8 for free! I loves these shoes. They have an extremely comfortable sole and I never got sore wearing these around. I’m moving and trying to downsize, so looking for a new home for these beauties.
#
# Post ID : 7714403656
#
# Posted Date : 2024-02-04 11:38
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Free diy twin daybed, storage bed
#
# URL of first image : https://images.craigslist.org/00l0l_1Q0e5r3E8PG_0uY0hq_600x450.jpg
#
# Description : Heavy duty . Made from recycled materials. Needs new home by tomorrow.
#
# Post ID : 7714404562
#
# Posted Date : 2024-02-04 11:40
#
# Last Updated Date : 2024-02-04 11:41
#
# *************************************************************************************************
# Title : Navy Size 8 Comfy slippers with outdoor sole BRAND NEW
#
# URL of first image : https://images.craigslist.org/00S0S_5YT1GAA2nHh_0t20CI_600x450.jpg
#
# Description : Giving away these comfy size 8 navy slippers with fuzzy lining and outdoor soles. They’re brand new, never worn. I received them as a gift but already had a pair.
#
# Post ID : 7714404664
#
# Posted Date : 2024-02-04 11:41
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : 2006 Tundra driver door
#
# URL of first image : https://images.craigslist.org/00x0x_55C7kFUipvd_0t20CI_600x450.jpg
#
# Description : Free
#
# Post ID : 7714404789
#
# Posted Date : 2024-02-04 11:41
#
# Last Updated Date : 2024-02-04 14:01
#
# *************************************************************************************************
# Title : Free toaster oven
#
# URL of first image : https://images.craigslist.org/00U0U_8K0rgqM3Vd4_1320MM_600x450.jpg
#
# Description : Free toaster oven, it works.
#
# Post ID : 7714405077
#
# Posted Date : 2024-02-04 11:42
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Free small desk
#
# URL of first image : https://images.craigslist.org/00i0i_a3PjkCuRLjd_0CI0t2_600x450.jpg
#
# Description : Free very light desk no longer needed. Got for free on CL in the past and is great for small spaces! Has a small drawer pictured. Light bc I think it is constructed of composite wood/board.
#
# Post ID : 7714406419
#
# Posted Date : 2024-02-04 11:45
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Mens Tommaso Shoes Size 14 compatible with Peloton
#
# URL of first image : https://images.craigslist.org/00O0O_8pdNDeuT15c_0t20CI_600x450.jpg
#
# Description : Brand new - never used
#
# Post ID : 7714406723
#
# Posted Date : 2024-02-04 11:46
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Ricoh Aficio 2027SP - Multifunction B&W Copier
#
# URL of first image : https://images.craigslist.org/00M0M_2qOwcydjWaW_0d40hq_600x450.jpg
#
# Description : Ricoh Aficio 2027SP - Multifunction Black &amp; White Copier.  We have been using it fine, paper jammed.  Need to have a major service/tune-up on the machine and it should run for awhile.  It comes with Letter and Legal paper trays with storage cabinet on the bottom.  It's located on a second floor of an office.  Need a dolly cart and/or two persons to carry it downstairs.
#
# Post ID : 7714407703
#
# Posted Date : 2024-02-04 11:49
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Chair, broken stool, plastic bin
#
# URL of first image : https://images.craigslist.org/00O0O_e6RSQYPBgoC_0t20CI_600x450.jpg
#
# Description : Free stuff getting wet at curb
#
# Post ID : 7714409180
#
# Posted Date : 2024-02-04 11:53
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Queen Headboard
#
# URL of first image : https://images.craigslist.org/00c0c_kdDeW2nm3OX_0CI0t2_600x450.jpg
#
# Description : Solid wood queen headboard
#
# Post ID : 7714410406
#
# Posted Date : 2024-02-04 11:57
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Recessed Lighting hardware and dishwasher drain pipe
#
# URL of first image : https://images.craigslist.org/00v0v_gz8MtY1h9Eq_0CI0t2_600x450.jpg
#
# Description : Used but fully functional recessed lighting hardware
#
# Post ID : 7714411128
#
# Posted Date : 2024-02-04 11:59
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Baby Jogger Stroller Adaptor for Infant Car Seat
#
# URL of first image : https://images.craigslist.org/00L0L_3nXTs5LzGUH_0MM132_600x450.jpg
#
# Description : You need to already have a Baby Jogger Stroller and one of the compatible car seats to use this adaptor.   Car seats that will work with this adaptor include:
#
# Post ID : 7714411585
#
# Posted Date : 2024-02-04 12:00
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Free 8x10 Wool Rug
#
# URL of first image : https://images.craigslist.org/00808_hTK7zoLEvqH_0t20CI_600x450.jpg
#
# Description : Free, colorful 8x10 wool rug. It’s only 2-3 years old. We have pets so cleaning suggested before using.
#
# Post ID : 7714411641
#
# Posted Date : 2024-02-04 12:01
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Farmhouse style hutch
#
# URL of first image : https://images.craigslist.org/00707_4fi0fM38mvb_0dY0ja_600x450.jpg
#
# Description : Free hutch. Painted with rainbows inside the doors.
#
# Post ID : 7714412081
#
# Posted Date : 2024-02-04 12:02
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Nespresso Citiz
#
# URL of first image : https://images.craigslist.org/00909_1e40KFGEfq6_0gh0t2_600x450.jpg
#
# Description : Nespresso Citiz.  Does not have water tank or milk frother.  Well used.  Still works, though leaks a bit more than it should into the pod discard basket.  Parts are all in good shape.
#
# Post ID : 7714412252
#
# Posted Date : 2024-02-04 12:02
#
# Last Updated Date : 2024-02-04 13:22
#
# *************************************************************************************************
# Title : Free 5x7 Wool Rug
#
# URL of first image : https://images.craigslist.org/00k0k_gscZyimTLly_0ap0cY_600x450.jpg
#
# Description : Free area rug.
#
# Post ID : 7714412364
#
# Posted Date : 2024-02-04 12:03
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : FREE Flower Vases
#
# URL of first image : https://images.craigslist.org/00Z0Z_jgVqn35YjHN_0CI0t2_600x450.jpg
#
# Description : Free glass flower vases - various sizes
#
# Post ID : 7714414681
#
# Posted Date : 2024-02-04 12:09
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Commercial and Household Electrical Supplies
#
# URL of first image : https://images.craigslist.org/00h0h_4ZLl5g6QWUA_0t20CI_600x450.jpg
#
# Description : Household and Commercial Electrical Equipment $10 for everything
#
# Post ID : 7714415886
#
# Posted Date : 2024-02-04 12:12
#
# Last Updated Date : 2024-02-04 16:30
#
# *************************************************************************************************
# Title : wood desk
#
# URL of first image : https://images.craigslist.org/00S0S_ctrFiTFSI6v_0CI0t2_600x450.jpg
#
# Description : Solid wood desk
#
# Post ID : 7714419923
#
# Posted Date : 2024-02-04 12:24
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Car Audio Ground Loop Noise Isolator
#
# URL of first image : https://images.craigslist.org/01717_eqJlEIlCp5G_0x70t2_600x450.jpg
#
# Description : Car Audio Ground Loop Noise Isolator, 3.5 mm audio cable
#
# Post ID : 7714419996
#
# Posted Date : 2024-02-04 12:24
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Lamp
#
# URL of first image : https://images.craigslist.org/00e0e_7VFm40mLcUE_0t20CI_600x450.jpg
#
# Description : Free lamp.
#
# Post ID : 7714420130
#
# Posted Date : 2024-02-04 12:24
#
# Last Updated Date : 2024-02-04 12:28
#
# *************************************************************************************************
# Title : Wooden chairs
#
# URL of first image : https://images.craigslist.org/00F0F_efQIEClanQH_0t20CI_600x450.jpg
#
# Description : Five free wooden chairs.
#
# Post ID : 7714420998
#
# Posted Date : 2024-02-04 12:27
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Free step stool, water cube
#
# URL of first image : https://images.craigslist.org/00d0d_1WSk8krbTea_0t20CI_600x450.jpg
#
# Description : Step stool works perfectly but could use a de-dusting
#
# Post ID : 7714421201
#
# Posted Date : 2024-02-04 12:28
#
# Last Updated Date : 2024-02-04 13:26
#
# *************************************************************************************************
# Title : Bike rack for car
#
# URL of first image : https://images.craigslist.org/00O0O_6tJE0zJLc8Z_0t20CI_600x450.jpg
#
# Description : Rear mount bike rack that holds two bikes, comfortably on the back of a station wagon or hatchback. Free for the taking. Come and get it.
#
# Post ID : 7714421513
#
# Posted Date : 2024-02-04 12:29
#
# Last Updated Date : 2024-02-04 12:46
#
# *************************************************************************************************
# Title : Coffee Table & Side piece. + Iron wicker shelf
#
# URL of first image : https://images.craigslist.org/00v0v_bdqKSZ47kUu_07B09Y_600x450.jpg
#
# Description : Clearing out old furniture. Coffee table and matching side piece. Solid wood  .. Its labeled as Ernest Hemingway Collections by Thomasville. Sturdy and probable can be refinished as it needs some TLC. The wicker shelves is actually wound around a heavy steal frame. Its got some issues but could be re done or the steam frame repurposed. Also a basket and some marble pieces. Its all going to the dump Wednesday if not taken. I am around Sunday Monday Tuesday for pic up. I am located near Summit Store.
#
# Post ID : 7714423059
#
# Posted Date : 2024-02-04 12:33
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Free on Curb Double Pane Window
#
# URL of first image : https://images.craigslist.org/00x0x_y85WkmmO85_0t20CI_600x450.jpg
#
# Description : 2 years old. 60x42 window.
#
# Post ID : 7714423952
#
# Posted Date : 2024-02-04 12:35
#
# Last Updated Date : 2024-02-04 16:20
#
# *************************************************************************************************
# Title : Mostly Children’s DVDs
#
# URL of first image : https://images.craigslist.org/00n0n_iIMsboNFroN_0CI0t2_600x450.jpg
#
# Description : Preference to someone with kids who will watch these vs. reselling them.
#
# Post ID : 7714424146
#
# Posted Date : 2024-02-04 12:36
#
# Last Updated Date : 2024-02-04 13:00
#
# *************************************************************************************************
# Title : Free baby things!
#
# URL of first image : https://images.craigslist.org/00606_jMLGoeIYq0H_0t20CI_600x450.jpg
#
# Description : Looking for new homes for several baby items that I received hand me down. Some are more used than others!
#
# Post ID : 7714427235
#
# Posted Date : 2024-02-04 12:45
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : 15 Heavy-duty Pallets (free)
#
# URL of first image : https://images.craigslist.org/00g0g_imrkla4eDLQ_0Cz0t2_600x450.jpg
#
# Description : I have 15 heavy duty pallets left over from a retaining wall project. They are in good condition and free to pick up.
#
# Post ID : 7714427624
#
# Posted Date : 2024-02-04 12:46
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Sonoma County vintage visitors' brochure
#
# URL of first image : https://images.craigslist.org/00b0b_1Q3BfXj7jPv_0mL0t2_600x450.jpg
#
# Description : Illustrated brochure for visitors to Sonoma County, published in 1972 by the Santa Rosa Chamber of Commerce. Sixteen pages of text and photos. Map and listing of the county's 28 wineries (425 now!).
#
# Post ID : 7714428428
#
# Posted Date : 2024-02-04 12:48
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Free Heater Filters
#
# URL of first image : https://images.craigslist.org/00v0v_ftVSqY3e9GY_0t20CI_600x450.jpg
#
# Description : We replaced our heater and no longer need these. Please let me know when you can come by, and that you are a human, and I’ll leave them on my porch for you.
#
# Post ID : 7714429176
#
# Posted Date : 2024-02-04 12:51
#
# Last Updated Date : 2024-02-04 12:51
#
# *************************************************************************************************
# Title : FREE Mahjong / Poker / Chinese Chess / Game Table in Good Condition
#
# URL of first image : https://images.craigslist.org/00u0u_4y7RbGyXhK7_0CI0t2_600x450.jpg
#
# Description : FREE Mahjong / Poker / Chinese Chess / Game Table
#
# Post ID : 7714429617
#
# Posted Date : 2024-02-04 12:52
#
# Last Updated Date : 2024-02-04 13:30
#
# *************************************************************************************************
# Title : Tiny pill boxes
#
# URL of first image : https://images.craigslist.org/01212_3kcqfwDJk5N_0cg0bh_600x450.jpg
#
# Description : 1950s-era metal pill boxes.
#
# Post ID : 7714430250
#
# Posted Date : 2024-02-04 12:54
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Queen size mattress + cover
#
# URL of first image : Image unavailable
#
# Description : Hi, looking to get rid of a queen size mattress. Comes with a cover for top half and bottom. Great condition. Can pick up closer to the weekend, Friday/Saturday would be best but before that ok too. Beryessa/Penitencia.
#
# Post ID : 7714430819
#
# Posted Date : 2024-02-04 12:56
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Yellow gari
#
# URL of first image : https://images.craigslist.org/00k0k_lrlgm4CYKYa_0lM0CI_600x450.jpg
#
# Description : Yellow gari, West African ingredient. Recently purchased. Bag unopened. Message me on the Craigslist app for address for porch pickup.
#
# Post ID : 7714431142
#
# Posted Date : 2024-02-04 12:56
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Vintage hotel give-aways
#
# URL of first image : https://images.craigslist.org/00E0E_ixnLrXEi94p_0co0dj_600x450.jpg
#
# Description : Assorted soaps, matches, etc.  SF Children's Hospital circa 1940; a hotel in Yugoslavia (when there was such a country) 1980s; and more.
#
# Post ID : 7714432158
#
# Posted Date : 2024-02-04 12:59
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : HP Laserjet Pro 400, M401 Printer
#
# URL of first image : https://images.craigslist.org/00m0m_6gKSAq1bBt1_0ak07K_600x450.jpg
#
# Description : HP Laserjet Pro 400, M401 Printer - excellent condition.  Not wireless, but can connect to a network via an ethernet cable.  Includes power and usb connection cables.  Cartridge is low on toner, so a new cartridge will be needed in the near future.
#
# Post ID : 7714432214
#
# Posted Date : 2024-02-04 13:00
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : New Medical Convalescent Equip. Never used.
#
# URL of first image : https://images.craigslist.org/01313_8Zk0AXGAssv_0t20CI_600x450.jpg
#
# Description : Brand new commode &amp; walker. Never used. kaiser insisted he needed these. He didn’t. Yours if you need them.
#
# Post ID : 7714433007
#
# Posted Date : 2024-02-04 13:02
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Hanger from French Line Liberte
#
# URL of first image : https://images.craigslist.org/00T0T_eZyHMu9P1Me_0co08K_600x450.jpg
#
# Description : From the steamship Liberte, circa 1959.
#
# Post ID : 7714433430
#
# Posted Date : 2024-02-04 13:03
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Free Trampoline (10') Disassembled
#
# URL of first image : https://images.craigslist.org/00F0F_7kBl7v34UA2_0CI0t2_600x450.jpg
#
# Description : I am looking for a new home for a 10' trampoline, well loved.
#
# Post ID : 7714434867
#
# Posted Date : 2024-02-04 13:06
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Corner computer desk
#
# URL of first image : Image unavailable
#
# Description : Excellent condition corner computer desk.
#
# Post ID : 7714435381
#
# Posted Date : 2024-02-04 13:08
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Bits and bobs
#
# URL of first image : https://images.craigslist.org/00h0h_6aMH3aXCCGm_0cA0gM_600x450.jpg
#
# Description : Assorted bits and bobs: Infant of Prague medal; Sheffield steel blade with Bakelite (?) handle; polished stone; buttons; etc.
#
# Post ID : 7714435921
#
# Posted Date : 2024-02-04 13:09
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Free vintage tack box - wall mount
#
# URL of first image : https://images.craigslist.org/00l0l_7XWf67Ge83V_0MM132_600x450.jpg
#
# Description : Vintage tack box, sturdy wood, excellent condition
#
# Post ID : 7714437085
#
# Posted Date : 2024-02-04 13:12
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Free wood etc from kitchen and bath remodel
#
# URL of first image : https://images.craigslist.org/00404_ctErdpoFPYK_0CI0t2_600x450.jpg
#
# Description : Free! Come pick any wood, sinks, cabinets, etc. from our remodel. It all goes in the dumpster on Tuesday.
#
# Post ID : 7714437103
#
# Posted Date : 2024-02-04 13:12
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Hp colorjet 2605dn for parts or repair
#
# URL of first image : https://images.craigslist.org/00I0I_b5LbacMxGDw_0lM0CI_600x450.jpg
#
# Description : Hp colorjet laser color printer for parts or repair.
#
# Post ID : 7714437197
#
# Posted Date : 2024-02-04 13:12
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : La Z Boy Urban Attitudes Carlyle High Leg Recliner
#
# URL of first image : https://images.craigslist.org/00u0u_5lU6u6YMWcA_0DF0MW_600x450.jpg
#
# Description : Brown mahogany arms with beige chenille fabric, seen better days looks-wise, but still comfortable and substantial. Pushback recliner supports reclined position as show in the one photo and reclined flat position for napping. Recently replaced and we don't have room to keep both. Delivery negotiable
#
# Post ID : 7714438251
#
# Posted Date : 2024-02-04 13:15
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Women’s clothing - good condition
#
# URL of first image : https://images.craigslist.org/00M0M_aMtuEI5P7nn_0CI0t2_600x450.jpg
#
# Description : Two bags of women’s clothing. Size s-m. I’m a size 6. Good condition, mix of stuff. T-shirts, jumpsuits, flannel, etc. Come pick up today near mission &amp; precita.
#
# Post ID : 7714439336
#
# Posted Date : 2024-02-04 13:18
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Free ceiling fan. Fully functional, in great shape.
#
# URL of first image : https://images.craigslist.org/00101_a3SpnjJJO8M_0sF0CI_600x450.jpg
#
# Description : Switched out our ceiling lighting in our bedroom, free ceiling fan first-come-first-serve. Located in Rockridge.
#
# Post ID : 7714439415
#
# Posted Date : 2024-02-04 13:18
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : BLOOD GLOUCOSE MONITOR SYSTEM New, not opened
#
# URL of first image : Image unavailable
#
# Description : Come pick up at my house in Petaluma on Peta. Blvd. South
#
# Post ID : 7714440682
#
# Posted Date : 2024-02-04 13:22
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Bike Bags, you need to have a rack on bicycle. to use these.
#
# URL of first image : Image unavailable
#
# ...
#
# Post ID : 7714506486
#
# Posted Date : 2024-02-04 17:09
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : stroller cup holder
#
# URL of first image : https://images.craigslist.org/00b0b_38zgfHTrSgj_0t20CI_600x450.jpg
#
# Description : attaches to any stroller, porch pickup
#
# Post ID : 7714506573
#
# Posted Date : 2024-02-04 17:09
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Chicco keyfit car seat & car base (both EXPIRED): can use for trade in
#
# URL of first image : https://images.craigslist.org/00z0z_7uSHxEj0mty_0gW0mO_600x450.jpg
#
# Description : Chicco Keyfit car seat + base are both expired
#
# Post ID : 7714506798
#
# Posted Date : 2024-02-04 17:10
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : FREE BLENDER Waring Pro
#
# URL of first image : https://images.craigslist.org/00R0R_ho6HBAbXhY0_0t20CI_600x450.jpg
#
# Description : Great “pro” blender just needs clear new plastic plug on top .
#
# Post ID : 7714506823
#
# Posted Date : 2024-02-04 17:10
#
# Last Updated Date : 2024-02-04 17:11
#
# *************************************************************************************************
# Title : Little Bench (PENDING)
#
# URL of first image : https://images.craigslist.org/00t0t_hFdjSxRSF3a_0ww0oo_600x450.jpg
#
# Description : Little metal bench - we tried to reupholster and cut the faux leather fabric incorrectly so it does need to be reupholstered still, but free if you'd like it.
#
# Post ID : 7714506962
#
# Posted Date : 2024-02-04 17:11
#
# Last Updated Date : 2024-02-04 18:32
#
# *************************************************************************************************
# Title : Co-Sleeper bedside bassinet and play yard
#
# URL of first image : https://images.craigslist.org/00Y0Y_lGg7utxHxLd_0t20CI_600x450.jpg
#
# Description : Co-Sleeper bedside bassinet and playard. Transforms into multiple configurations. Able to extend your mattress and box springs to make sure the baby is sleeping in it his or her own bed.
#
# Post ID : 7714508053
#
# Posted Date : 2024-02-04 17:15
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Free 22” bike tube
#
# URL of first image : https://images.craigslist.org/00p0p_fZqW70bRjiN_0e80i5_600x450.jpg
#
# Description : New 22” bike tube
#
# Post ID : 7714508968
#
# Posted Date : 2024-02-04 17:19
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Hair Care Products, Deodorant
#
# URL of first image : https://images.craigslist.org/00000_bdxKnNNK42d_0t20CI_600x450.jpg
#
# Description : These have all been used slightly.  Please let me know if you're interested in any or all of them.  We can meet at Lucky's on McKee Road since my place is so hard to find.  Please leave your cell for ease of coordination.
#
# Post ID : 7714510842
#
# Posted Date : 2024-02-04 17:28
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Play Yard for Kids or Pets
#
# URL of first image : https://images.craigslist.org/00505_4ZkGda7pkLm_0t20CI_600x450.jpg
#
# Description : Wooden play yard with 14 panels in great condition.  Can be configured into any shape.  Older model of the Frisco Wood &amp; Metal 8-Panel Configurable Gate &amp; Playpen that you can see on Chewy.com.  Great for kids or pets.
#
# Post ID : 7714512536
#
# Posted Date : 2024-02-04 17:36
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Cherry wood bookcase - Free
#
# URL of first image : https://images.craigslist.org/00G0G_4ItImcdT8he_0t20CI_600x450.jpg
#
# Description : Cherry hardwood bookcase.  Center shelf is fixed, all the rest are adjustable, quality construction.
#
# Post ID : 7714512690
#
# Posted Date : 2024-02-04 17:37
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : 3 IKEA Kolbjorn Metal Shelves (unassembled)
#
# URL of first image : https://images.craigslist.org/00707_8dgz6iO42UW_0t20CI_600x450.jpg
#
# Description : 3 Kolbjorn Metal Shelves from IKEA, in beige color.  These are unassembled, still flat packed in boxes.
#
# Post ID : 7714513275
#
# Posted Date : 2024-02-04 17:40
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Black Bamboo Stakes (Phyllostachys Nigra)
#
# URL of first image : https://images.craigslist.org/01313_1iARDpHajuW_07K0ak_600x450.jpg
#
# Description : Thinning my backyard bamboo for the past 6 months. Plants were established in 2008 so some of the stakes are outdoor appropriate while others are perfect for staking houseplants.  Basically, stakes range from 1 inch to 4 inches in diameter 20 – 70 inches height.
#
# Post ID : 7714513552
#
# Posted Date : 2024-02-04 17:41
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Chappywrap Blanket
#
# URL of first image : https://images.craigslist.org/00V0V_4Ps9Uf9cG5s_0t20CI_600x450.jpg
#
# Description : In great condition. Large size. Thought I’d use for my daughter’s room but didn’t work for the room.
#
# Post ID : 7714514479
#
# Posted Date : 2024-02-04 17:46
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Queen matress
#
# URL of first image : https://images.craigslist.org/00808_9zy8KaqfSHL_0t20CI_600x450.jpg
#
# Description : Used queen mattress in good condition, free
#
# Post ID : 7714514707
#
# Posted Date : 2024-02-04 17:47
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Desk with plenty of storage
#
# URL of first image : https://images.craigslist.org/00000_9ItRcsBmw3S_0ww0ii_600x450.jpg
#
# Description : Dark wood, bronze fixtures, black top
#
# Post ID : 7714514967
#
# Posted Date : 2024-02-04 17:49
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Estate Sale,  Very big, 2 flats and garage - Now Free
#
# URL of first image : Image unavailable
#
# Description : Estate Sale,  Very big, 2 flats and garage - Now Free
#
# Post ID : 7714515494
#
# Posted Date : 2024-02-04 17:51
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : FREE cookeare pots and pans in good to very good condition
#
# URL of first image : https://images.craigslist.org/00U0U_3NrWl5k9Yg0_0CI0t2_600x450.jpg
#
# Description : Just bought a new cookware set so giving these away.
#
# Post ID : 7714516674
#
# Posted Date : 2024-02-04 17:58
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Three picture frames
#
# URL of first image : https://images.craigslist.org/01414_7p11yGXooWj_0CI0t2_600x450.jpg
#
# Description : Largest one has a 19.5x23.5 (the one with red edging), smallest one is 11.5x11.5 (with the large moon), medium is 13.5x10.5 (with the multicolors, no glass). All in good condition. Must take all 3.
#
# Post ID : 7714516914
#
# Posted Date : 2024-02-04 17:59
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Woven Laundry Basket
#
# URL of first image : https://images.craigslist.org/00B0B_9FB0m85kkH7_0t20CI_600x450.jpg
#
# Description : Woven Laundry basket with canvas insert - in good condition from pet and smoke free home
#
# Post ID : 7714517912
#
# Posted Date : 2024-02-04 18:04
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Small couch
#
# URL of first image : https://images.craigslist.org/00000_dicqJsIR1Jv_0CI0t2_600x450.jpg
#
# Description : Clean, gently-used, brown faux-leather couch.
#
# Post ID : 7714520370
#
# Posted Date : 2024-02-04 18:17
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Drafting table
#
# URL of first image : https://images.craigslist.org/00B0B_e5htczH8wf7_0t20CI_600x450.jpg
#
# Description : Soft vinyl type surface for writing or drawing on, very heavy duty, no legs.
#
# Post ID : 7714521653
#
# Posted Date : 2024-02-04 18:24
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Rug
#
# URL of first image : https://images.craigslist.org/00I0I_hQD3R1KqUmJ_0t20CI_600x450.jpg
#
# Description : Free Rug
#
# Post ID : 7714523278
#
# Posted Date : 2024-02-04 18:33
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Lots of good boxes for free
#
# URL of first image : Image unavailable
#
# Description : Just come and pick them up. Various sizes (mostly small and medium, some large). All perfectly clean and in excellent shape.
#
# Post ID : 7714524888
#
# Posted Date : 2024-02-04 18:42
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Walgreens Ultrasonic Humidifier for Free
#
# URL of first image : https://images.craigslist.org/00j0j_gsfCedDgbTR_0lM0t2_600x450.jpg
#
# Description : We have a Walgreens/Sunbeam Ultrasonic Humidifier, that has only been used a couple times, to offer for FREE.  Just hoping someone can use it.  If you are interested, please let me know and share your contact info to arrange a pick up.
#
# Post ID : 7714526026
#
# Posted Date : 2024-02-04 18:49
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : 3 sinks * Free delivery Monday 2/5 10 am Berkeley, Oakland, Emeryville
#
# URL of first image : https://images.craigslist.org/00j0j_dU5CDQvwNNH_0CI0m3_600x450.jpg
#
# Description : To your place or to the dump.
#
# Post ID : 7714528699
#
# Posted Date : 2024-02-04 19:05
#
# Last Updated Date : 2024-02-04 19:21
#
# *************************************************************************************************
# Title : Chair
#
# URL of first image : https://images.craigslist.org/00N0N_VbEoyq7hdg_0lR0t2_600x450.jpg
#
# Description : Haul it away asap.
#
# Post ID : 7714529410
#
# Posted Date : 2024-02-04 19:09
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : HP Color LaserJet CP1518ni
#
# URL of first image : https://images.craigslist.org/00f0f_lgBTGpaSzEV_0t20CI_600x450.jpg
#
# Description : free HP Color LaserJet CP1518ni
#
# Post ID : 7714529428
#
# Posted Date : 2024-02-04 19:10
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Book ends
#
# URL of first image : https://images.craigslist.org/01515_5VHn57cFnuN_0t20CI_600x450.jpg
#
# Description : Nice and heavy
#
# Post ID : 7714529989
#
# Posted Date : 2024-02-04 19:13
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : DRAFTING STOOL
#
# URL of first image : https://images.craigslist.org/00u0u_bUcU5FBWbLa_0t20CI_600x450.jpg
#
# Description : Pneumatic 21”- 30” seat height
#
# Post ID : 7714530054
#
# Posted Date : 2024-02-04 19:14
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Free lamps.
#
# URL of first image : https://images.craigslist.org/01717_l54rAghHhjG_0t20CI_600x450.jpg
#
# Description : Must take a pair. Near DVC
#
# Post ID : 7714530780
#
# Posted Date : 2024-02-04 19:18
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Kid Science Kit - FREE!
#
# URL of first image : https://images.craigslist.org/00Y0Y_lycHwQ0boX2_1320MM_600x450.jpg
#
# Description : Looking to give away this used kids science kit.
#
# Post ID : 7714532990
#
# Posted Date : 2024-02-04 19:33
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Free Computer Monitor
#
# URL of first image : https://images.craigslist.org/00j0j_7CydR1rm06w_0CI0sP_600x450.jpg
#
# Description : Had this monitor in storage and no longer need it. It has a vga connection and I had bought an hdmi converter and I'm including it with this monitor.
#
# Post ID : 7714533705
#
# Posted Date : 2024-02-04 19:38
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Box of breastmilk storage bags
#
# URL of first image : https://images.craigslist.org/00404_7mVgJAqHeO0_0MM132_600x450.jpg
#
# Description : Pick up only. Text
#
# Post ID : 7714534032
#
# Posted Date : 2024-02-04 19:40
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Built-in Counter-depth Kitchenaid KSSC36QTS Architect Series II
#
# URL of first image : Image unavailable
#
# Description : Built-in Counter-depth Kitchenaid KSSC36QTS Architect Series II refrigerator. It doesn’t maintain temperature so will require some expertise to fix it. New one costs $12,000 so if you can fix it, you can make some profit. I upgraded so don’t need this anymore.
#
# Post ID : 7714535179
#
# Posted Date : 2024-02-04 19:48
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : IKEA Laptop Stand/Bed Tray
#
# URL of first image : https://images.craigslist.org/00z0z_fRQDPWIf3ce_0CI0hq_600x450.jpg
#
# Description : Gifting this laptop stand/bed tray in great condition. No longer needed.
#
# Post ID : 7714535545
#
# Posted Date : 2024-02-04 19:51
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Twin size bed frame
#
# URL of first image : https://images.craigslist.org/00W0W_5uUBk9NFhYk_0t20t2_600x450.jpg
#
# Description : Giving away a twin size bed frame. It was part of a bunk bed set. Great for kids.
#
# Post ID : 7714536307
#
# Posted Date : 2024-02-04 19:56
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************
# Title : Free Antique Floor Standing Radio and Walker
#
# URL of first image : https://images.craigslist.org/00t0t_47tcybhKCXT_0t20CI_600x450.jpg
#
# Description : I am giving away the Free Antique Floor Standing Radio and Walker in the images shown. I am located in Antioch.
#
# Post ID : 7714536489
#
# Posted Date : 2024-02-04 19:57
#
# Last Updated Date : Last updated date not available
#
# *************************************************************************************************

# %% [markdown]
# ### Automating Login on The Old Reader

# %% [markdown]
# - Account created with username: adiallmight@gmail.com; password: a7pute

# %%
## Get signing page and form

headers = {'User-Agent': 'Mozilla/5.0'}
url = 'https://theoldreader.com/users/sign_in'

page = requests.get(url, headers)

soup = BeautifulSoup(page.content, 'html.parser')

# %% [markdown]
# #### Exploring the Login Mechanism
# - From the form, it can be observed that the username field has a name: user[login] and the password field has the name: user[password].
# - The code below captures it

# %%
## Use form ID to access form body

form = soup.select_one('#new_user')

token = form.select_one('input[name = authenticity_token]') ## Get authenticity token

## Authenticity token is required in the POST request payload 

authenticity_token = token.get('value')

user_name = soup.select_one('#user_login').get('name')  ## Get username key

password = soup.select_one('#user_password').get('name')  ## Get password key

print(f'The following are the keys for the information needed in the payload for POST i.e log in: \nAuthenticity token : {authenticity_token} \nUser name: {user_name} \nPassword: {password}')
# Out:
# The following are the keys for the information needed in the payload for POST i.e log in:
# Authenticity token : WL79O6JXKexrL+SwPVFCTiVTdH5a5nyjrRLBfpZ5Dxs=
# User name: user[login]
# Password: user[password]

# %% [markdown]
# #### Analyzing Network Traffic for Login Request
# - A POST request is made when signing in.
# - This is because the user name and password are being submitted with some other information to the website to start the log in session and create a cookie for it
# - Also, it can be observed from the payload information that the name of the Username and Password fields were submitted along with the Authenticity token in the POST request.

# %% [markdown]
# #### Automating the Login Process

# %%
time.sleep(10)  ## Pause before next request

session = requests.session()

## Use POST method to get cookie for the session

session.post("https://theoldreader.com/users/sign_in",
            data = {
                'authenticity_token': authenticity_token,
                user_name : 'adiallmight@gmail.com',
                password : 'a7pute',
                'commit': 'Sign In'
            },
            timeout = 20)
cookies = session.cookies.get_dict()

# %% [markdown]
# #### Verifying Successful Login

# %%
print(cookies)
# Out:
# {'remember_user_token': 'BAhbB1sGVToaTW9wZWQ6OkJTT046Ok9iamVjdElkIhHivxufea%2FsmLJAvRxJIiIkMmEkMDUkbmUwUmlKMThVWEszdm5wRVhkUnNaLgY6BkVU--7545f382ff3d3b199f080ef4f4cb5a2fc94835c7', 'i_know_you': 'Aditya+Satpute', '_new_reader_session': 'BAh7CkkiD3Nlc3Npb25faWQGOgZFVEkiJTBlMGExNmY1NTc4MGZkNDYyOTgyZWNlZGZiOGQxNGJiBjsAVEkiGXdhcmRlbi51c2VyLnVzZXIua2V5BjsAVFsHWwZVOhpNb3BlZDo6QlNPTjo6T2JqZWN0SWQiEeK%2FG595r%2ByYskC9HEkiIiQyYSQwNSRuZTBSaUoxOFVYSzN2bnBFWGRSc1ouBjsAVEkiDWxhbmd1YWdlBjsARjoHZW5JIhByZWRpcmVjdF90bwY7AEZJIgYvBjsARkkiEF9jc3JmX3Rva2VuBjsARkkiMUNwc2RLWXNkcjNoWjhnb2hhRGxNSWJOVUtJOTZCYkIzQ3Y5Y3VBQVZ2TTQ9BjsARg%3D%3D--98c04f4a8832d184be74054c524b07f93694c22e', 'signed_at': '1707117683'}

# %%
## Check if successfully logged in by accesing the home page

time.sleep(10)

url2 = 'https://theoldreader.com/'
home_page = session.get(url, cookies = cookies)

soup2 = BeautifulSoup(home_page.content, 'html.parser')

# %%
pattern = re.compile("Aditya Satpute")
ele = soup2.find(string = pattern)
ele.parent
# Out:
# <script type="text/javascript">
#   if (typeof Bugsnag !== "undefined" && Bugsnag !== null) {
#     Bugsnag.releaseStage = "production";
#     Bugsnag.notifyReleaseStages = ['production'];
#     Bugsnag.user = {
#       id: "e2bf1b9f79afec98b240bd1c",
#       name: "Aditya Satpute",
#       email: "adiallmight@gmail.com"
#     }
#   }
# </script>

# %% [markdown]
# - Successfully logged in and verified by finding the html container containg ID, Name and email ID
